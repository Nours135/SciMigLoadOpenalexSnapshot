# %%
import json
with open('concepts/concepts.json', 'r', encoding='utf-8') as fp:
    final_result = json.load(fp)

# %%
import networkx as nx

# %%
ancestors_set = dict()
node_set = set()
G = nx.DiGraph()

for item in final_result:
    # print(item.keys())
    # step 1 添加节点
    ancestors = item['ancestors']
    myself = (item['display_name'], item['level'])
    ancestors = [(item['display_name'], item['level']) for item in ancestors]
    node_set.add(myself)
    for anc in ancestors:
        node_set.add(anc)
        # step 2 添加边
        # print(anc[1] - myself[1])
        if anc[1] - myself[1] == -1: # 只保留直系关系，ancestors字段会记录所有层级的祖先
            G.add_edge(anc[0], myself[0])

# 添加节点属性
node_levels = {item[0]: item[1]  for item in node_set}
# {'A': 'red', 'B': 'blue', 'C': 'green', 'D': 'yellow'}
nx.set_node_attributes(G, node_levels, 'level')

# 导出图
nx.write_gml(G, "concepts/concepts_tree.gml")

# %%
for n in G.nodes.data():
    if n[1]['level'] == 0:
        print(n)
# Out:
# ('Business', {'level': 0})
# ('Economics', {'level': 0})
# ('Biology', {'level': 0})
# ('Environmental science', {'level': 0})
# ('Medicine', {'level': 0})
# ('Chemistry', {'level': 0})
# ('Physics', {'level': 0})
# ('Computer science', {'level': 0})
# ('Materials science', {'level': 0})
# ('Political science', {'level': 0})
# ('Psychology', {'level': 0})
# ('Mathematics', {'level': 0})
# ('Geology', {'level': 0})
# ('Philosophy', {'level': 0})
# ('Engineering', {'level': 0})
# ('Sociology', {'level': 0})
# ('Geography', {'level': 0})
# ('History', {'level': 0})
# ('Art', {'level': 0})

# %%
# 获取节点 Computer Science 能够到达的所有节点
reachable_nodes = nx.single_source_shortest_path(G, 'Computer science')
# print("节点 'Medicine' 能够到达的所有节点：", reachable_nodes) # node -> shortest path
nodes_of_medicine = [(item, G.nodes[item]['level']) for item in reachable_nodes.keys()]
print(len(nodes_of_medicine))
nodes_of_medicine = sorted(nodes_of_medicine, key=lambda x:x[1])
level_count = dict()
for item in nodes_of_medicine:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
# nodes_of_medicine[-10:]

# 打印level 1 的节点
for item in nodes_of_medicine:
    if item[1] == 1:
        # print(item)
        pass

selected_level_1 = ['Artificial intelligence', 'Machine learning', 'Computer vision', 'Data mining', 'Natural language processing', 'Speech recognition', 'Computer graphics (images)']
# not_sure = ['Data science', 'Information retrieval', '']
# Out:
# 9266
# {0: 1, 1: 33, 2: 3164, 3: 3253, 4: 1480, 5: 1335}

# %%
# AI生成两份，
reachable_nodes = nx.single_source_shortest_path(G, 'Computer science')
# print("节点 'Medicine' 能够到达的所有节点：", reachable_nodes) # node -> shortest path
nodes_of_AI = [(item, G.nodes[item]['level']) for item in reachable_nodes.keys()]
print(len(nodes_of_AI))
nodes_of_AI = sorted(nodes_of_AI, key=lambda x:x[1])
level_count = dict()
for item in nodes_of_AI:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
# nodes_of_medicine[-10:]
# Out:
# 9266
# {0: 1, 1: 33, 2: 3164, 3: 3253, 4: 1480, 5: 1335}

# %%
with open('D:\SciMig\concepts/concepts_AI_full.json', 'w') as fp:
    json.dump(nodes_of_AI, fp)

# %%
nodes_of_AI = []
for level1 in selected_level_1:
    reachable_nodes = nx.single_source_shortest_path(G, level1)
    # print("节点 'Medicine' 能够到达的所有节点：", reachable_nodes) # node -> shortest path
    nodes_of_AI += [(item, G.nodes[item]['level']) for item in reachable_nodes.keys()]
    print(len(nodes_of_AI))
nodes_of_AI = sorted(nodes_of_AI, key=lambda x:x[1])
level_count = dict()
for item in nodes_of_AI:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
# nodes_of_medicine[-10:]
# Out:
# 2502
# 3252
# 4325
# 4556
# 4777
# 4907
# 5010
# {1: 7, 2: 1573, 3: 1963, 4: 842, 5: 625}

# %%
with open('D:\SciMig\concepts/concepts_AI_refined.json', 'w') as fp:
    json.dump(nodes_of_AI, fp)

# %%
# 获取节点 Medicine 能够到达的所有节点
reachable_nodes = nx.single_source_shortest_path(G, 'Medicine')
# print("节点 'Medicine' 能够到达的所有节点：", reachable_nodes) # node -> shortest path
nodes_of_medicine = [(item, G.nodes[item]['level']) for item in reachable_nodes.keys()]
print(len(nodes_of_medicine))
nodes_of_medicine = sorted(nodes_of_medicine, key=lambda x:x[1])
level_count = dict()
for item in nodes_of_medicine:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
# nodes_of_medicine[-10:]

# %%
with open('D:\SciMig\concepts/concepts_Medicine_l.json', 'w') as fp:
    json.dump(nodes_of_medicine, fp)

# %%
selected_medicine_concepts = []
for item in nodes_of_medicine:
    if item[1] == 1:
        selected_medicine_concepts.append(item)
    # level_count[item[1]] = level_count.get(item[1], 0) + 1
print(*selected_medicine_concepts, sep='\n')

# %%
# 获取节点 Medicine 能够到达的所有节点
reachable_nodes = nx.single_source_shortest_path(G, 'Physics')
# print("节点 'Medicine' 能够到达的所有节点：", reachable_nodes) # node -> shortest path
nodes_of_physic = [(item, G.nodes[item]['level']) for item in reachable_nodes.keys()]
nodes_of_physic = sorted(nodes_of_physic, key=lambda x:x[1])
print(len(nodes_of_physic))
level_count = dict()
for item in nodes_of_physic:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
nodes_of_physic[-10:]

# %%
selected_Physics_concepts = []
for item in nodes_of_physic:
    if item[1] == 4:
        selected_Physics_concepts.append(item)
    # level_count[item[1]] = level_count.get(item[1], 0) + 1
print(*selected_Physics_concepts, sep='\n')

# %%
with open('D:\SciMig\concepts/concepts_Physic_l.json', 'w') as fp:
    json.dump(nodes_of_physic, fp)

# %%
# 接下来获取，管理学的子图
reachable_nodes_management = nx.single_source_shortest_path(G, 'Economics')
reachable_nodes_business = nx.single_source_shortest_path(G, 'Business')
# reachable_nodes_Politiacl = nx.single_source_shortest_path(G, 'Political science')

# %%
subgraph_nodes = [i[0] for i in reachable_nodes_management.items()] + [i[0] for i in reachable_nodes_business.items()] # + [i[0] for i in reachable_nodes_Politiacl.items()]
print(len(subgraph_nodes))
management_related_subgraph = G.subgraph(subgraph_nodes)
# management_related_subgraph.to
nx.write_gml(management_related_subgraph, "concepts/concepts_tree_management.gml")
# Out:
# 6590

# %%
sorted(subgraph_nodes, key=len)
# Out:
# ['Debt',
#  'Bond',
#  'Cash',
#  'Loan',
#  'Lien',
#  'ROWE',
#  'XBRL',
#  'Wage',
#  'Lira',
#  'BRIC',
#  'Tort',
#  'CDIO',
#  'Clef',
#  'Oboe',
#  'Abia',
#  'CVAR',
#  'XPDL',
#  'OPM3',
#  'PDCA',
#  'PEVQ',
#  'Debt',
#  'Bond',
#  'Cash',
#  'Loan',
#  'Lien',
#  'ROWE',
#  'Dove',
#  'XBRL',
#  'Nike',
#  'Reel',
#  'Lira',
#  'BRIC',
#  'Tort',
#  'CVAR',
#  'PDCA',
#  'XPDL',
#  'PEVQ',
#  'Lease',
#  'LEAPS',
#  'Logit',
#  'Audit',
#  'Piano',
#  'Blues',
#  'Flute',
#  'Tying',
#  'Bluff',
#  'Purge',
#  'CUSUM',
#  'DPSIR',
#  'COBIT',
#  'Rupee',
#  'Libor',
#  'Crore',
#  'Plant',
#  'Viola',
#  'Cello',
#  'NAIRU',
#  'HRHIS',
#  'DMAIC',
#  'Lease',
#  'LEAPS',
#  'Audit',
#  'Bleed',
#  'Foley',
#  'COBIT',
#  'Rupee',
#  'Libor',
#  'Chilo',
#  'Media',
#  'NAIRU',
#  'Dacus',
#  'DMAIC',
#  'Alate',
#  'Estate',
#  'Issuer',
#  'Collar',
#  'Coupon',
#  'Ledger',
#  'Escrow',
#  'Surety',
#  'Excise',
#  'Barter',
#  'Probit',
#  'Sprint',
#  'Lyrics',
#  'Violin',
#  'Guitar',
#  'Eponym',
#  'Fyodor',
#  'Supply',
#  'Salary',
#  'Utopia',
#  'TOPSIS',
#  'Greeks',
#  'Tariff',
#  'Layoff',
#  'Kanban',
#  'CarSim',
#  'Cartel',
#  'Kaizen',
#  'Brexit',
#  'Maasai',
#  'Debtor',
#  'R-CAST',
#  'MULTOS',
#  'iTraxx',
#  'Estate',
#  'Issuer',
#  'Collar',
#  'Coupon',
#  'Ledger',
#  'Escrow',
#  'Surety',
#  'Vendor',
#  'Pallet',
#  'Tariff',
#  'Kaizen',
#  'Cartel',
#  'Brexit',
#  'Debtor',
#  'MULTOS',
#  'iTraxx',
#  'Finance',
#  'Economy',
#  'Payment',
#  'Revenue',
#  'Pension',
#  'Warrant',
#  'Default',
#  'Amenity',
#  'Netting',
#  'Tranche',
#  'Actuary',
#  'Poverty',
#  'Ex-ante',
#  'Rivalry',
#  'Chaotic',
#  'Sibling',
#  'Singing',
#  'Tapping',
#  'Payroll',
#  'Country',
#  'Minimax',
#  'Bidding',
#  'Lottery',
#  'Dumping',
#  'Receipt',
#  'Voucher',
#  'Invoice',
#  'Welfare',
#  'Subsidy',
#  'Fordism',
#  'Serfdom',
#  'Chaebol',
#  'Arrears',
#  'Accrual',
#  'PEG 400',
#  'FinTech',
#  'Tax law',
#  'mHealth',
#  'eHealth',
#  'Orality',
#  'Phonics',
#  'Bailout',
#  'p-value',
#  'Platoon',
#  'SemEval',
#  'Anagram',
#  'Ratchet',
#  'Vibrato',
#  'Duopoly',
#  'Autarky',
#  'IT risk',
#  'Annuity',
#  'Cadenza',
#  'Use tax',
#  'Subgame',
#  'Basel I',
#  'Finance',
#  'Payment',
#  'Revenue',
#  'Pension',
#  'Warrant',
#  'Default',
#  'Amenity',
#  'Netting',
#  'Tranche',
#  'Actuary',
#  'Loyalty',
#  'Bidding',
#  'Barcode',
#  'Receipt',
#  'Voucher',
#  'Payroll',
#  'Invoice',
#  'Bespoke',
#  'Signage',
#  'Eyewear',
#  'Opt-out',
#  'Dumping',
#  'Chaebol',
#  'Arrears',
#  'Accrual',
#  'PEG 400',
#  'FinTech',
#  'Tax law',
#  'Agrilus',
#  'IT risk',
#  'Annuity',
#  'Cutworm',
#  'Use tax',
#  'Commerce',
#  'Earnings',
#  'Dividend',
#  'Clearing',
#  'Goodwill',
#  'Breakout',
#  'Deferral',
#  'Keiretsu',
#  'Straddle',
#  'Executor',
#  'Literacy',
#  'Outreach',
#  'Donation',
#  'Slowdown',
#  'One-Step',
#  'Currency',
#  'Tax rate',
#  'Guardian',
#  'Taxpayer',
#  'Oil boom',
#  'Banknote',
#  'Quantile',
#  'Skewness',
#  'Schedule',
#  'Workflow',
#  'Workload',
#  'Turnover',
#  'Teamwork',
#  'Staffing',
#  'Coaching',
#  'Monopoly',
#  'Scarcity',
#  'Workbook',
#  'Stockout',
#  'Go/no go',
#  'Slippage',
#  'Drop out',
#  'Zip code',
#  'Megacity',
#  'Urbanity',
#  'Viet nam',
#  'Overtime',
#  'Churning',
#  'Overwork',
#  'Tanzania',
#  'Stumpage',
#  'Gulf war',
#  'Grossman',
#  'Lump sum',
#  'ATM card',
#  'Creditor',
#  'Bad debt',
#  'Eurobond',
#  'Fuel tax',
#  'Solvency',
#  'Bank run',
#  'Renminbi',
#  'Trilemma',
#  'Contango',
#  'Pieridae',
#  'Medicaid',
#  'CARE Act',
#  'Numeracy',
#  'Job loss',
#  'LonWorks',
#  'Anagrams',
#  'Due date',
#  'Big Four',
#  'Tent map',
#  'Demotion',
#  'Slugging',
#  'Concerto',
#  'Strategy',
#  'Ebidding',
#  'Workfare',
#  'Low wage',
#  'Resizing',
#  'Unbanked',
#  'Gift tax',
#  'Telecare',
#  'Marasmus',
#  'Basel II',
#  'Eauction',
#  'SERVQUAL',
#  'Fuzzball',
#  'Neurolaw',
#  'Job shop',
#  'Flat tax',
#  'Business',
#  'Commerce',
#  'Earnings',
#  'Dividend',
#  'Clearing',
#  'Goodwill',
#  'Breakout',
#  'Deferral',
#  'Keiretsu',
#  'Straddle',
#  'Executor',
#  'Stockout',
#  'Workbook',
#  'Headline',
#  'Start up',
#  'Lump sum',
#  'ATM card',
#  'Creditor',
#  'Bad debt',
#  'Eurobond',
#  'Fuel tax',
#  'Solvency',
#  'Bank run',
#  'Renminbi',
#  'Trilemma',
#  'Contango',
#  'Pieridae',
#  'Mealybug',
#  'Ebidding',
#  'Big Four',
#  'Resizing',
#  'Unbanked',
#  'Gift tax',
#  'SERVQUAL',
#  'Coccidae',
#  'Ostrinia',
#  'Acaridae',
#  'Eauction',
#  'Fuzzball',
#  'Economics',
#  'Portfolio',
#  'PEG ratio',
#  'Commodity',
#  'Cash flow',
#  'Liability',
#  'Convexity',
#  'Butterfly',
#  'Arbitrage',
#  'Ask price',
#  'Factoring',
#  'Bid price',
#  "Tobin's q",
#  'Worksheet',
#  'Laddering',
#  'Syndicate',
#  'Tail risk',
#  'Pro forma',
#  'Overdraft',
#  'Self-help',
#  'Workforce',
#  'Emulation',
#  'Excursion',
#  'Full-time',
#  'Recession',
#  'Short run',
#  'Covariate',
#  'Unit root',
#  'Moneyness',
#  'Numéraire',
#  'Chow test',
#  'Offensive',
#  'Making-of',
#  'Screaming',
#  'Open plan',
#  'Incentive',
#  'Collusion',
#  'Unit cost',
#  'Monopsony',
#  'Hierarchy',
#  'Manifesto',
#  'Spectacle',
#  'Precarity',
#  'Allotment',
#  'Decadence',
#  'Sweatshop',
#  'New class',
#  'Parallels',
#  'Lead time',
#  'Spin offs',
#  'Oil price',
#  'Arms race',
#  'Residence',
#  'Free zone',
#  'Trust law',
#  'Severance',
#  'Safeguard',
#  'Fur trade',
#  'Indemnity',
#  'City area',
#  'Ingenuity',
#  'On demand',
#  'Tick size',
#  'Innovator',
#  'Net worth',
#  'Spin-flip',
#  'Us dollar',
#  'Use value',
#  'Rationing',
#  'Self care',
#  'Skill mix',
#  'Andragogy',
#  'Cash crop',
#  'Yield gap',
#  'Deflation',
#  'Mid price',
#  'Tax court',
#  'Microgrid',
#  'Key space',
#  'Hénon map',
#  'Merit pay',
#  'Oligopoly',
#  'Welfarism',
#  'State law',
#  'Globalism',
#  'Globality',
#  'Wage rate',
#  'Six Sigma',
#  'Paid work',
#  'Accession',
#  'Sri lanka',
#  'Ivanovich',
#  'Club deal',
#  'Soft loan',
#  'Mass tort',
#  'Risk pool',
#  'Tax haven',
#  'Sales tax',
#  'Copayment',
#  'Sign test',
#  'Education',
#  'Bank rate',
#  'Tardiness',
#  'Basel III',
#  'Game tree',
#  'Scots law',
#  'Term loan',
#  'Loan sale',
#  'Dead code',
#  'Open shop',
#  'Proxy bid',
#  'Tax basis',
#  'Write-off',
#  'Marketing',
#  'Portfolio',
#  'PEG ratio',
#  'Commodity',
#  'Cash flow',
#  'Liability',
#  'Convexity',
#  'Butterfly',
#  'Arbitrage',
#  'Ask price',
#  'Factoring',
#  'Bid price',
#  "Tobin's q",
#  'Worksheet',
#  'Laddering',
#  'Syndicate',
#  'Tail risk',
#  'Pro forma',
#  'Overdraft',
#  'Self-help',
#  'Publicity',
#  'Lead time',
#  'Warehouse',
#  'Franchise',
#  'Unit load',
#  'Collusion',
#  'Spin offs',
#  'Fake news',
#  'Newspaper',
#  'Making-of',
#  'Superstar',
#  'Coca cola',
#  'Safeguard',
#  'Fur trade',
#  'Free zone',
#  'Indemnity',
#  'On demand',
#  'Tick size',
#  'Innovator',
#  'Net worth',
#  'Spin-flip',
#  'Us dollar',
#  'Use value',
#  'Homoptera',
#  'Noctuidae',
#  'Pyralidae',
#  'Thripidae',
#  'Crambidae',
#  'Trap crop',
#  'Six Sigma',
#  'Space Age',
#  'Accession',
#  'Ivanovich',
#  'Club deal',
#  'Soft loan',
#  'Mass tort',
#  'Risk pool',
#  'Tax haven',
#  'Sales tax',
#  'Aphididae',
#  'Heliothis',
#  'Space law',
#  'Scots law',
#  'Term loan',
#  'Loan sale',
#  'Proxy bid',
#  'Management',
#  'Accounting',
#  'Commission',
#  'Bankruptcy',
#  'Collateral',
#  'Hedge fund',
#  'Divestment',
#  'Insolvency',
#  'Fair value',
#  'Net income',
#  'Prospectus',
#  'Contrarian',
#  'Seed money',
#  'For profit',
#  'Put option',
#  'Perpetuity',
#  'Face value',
#  'Rebranding',
#  'Trust fund',
#  'Legal risk',
#  'Curriculum',
#  'Attendance',
#  'Prosperity',
#  'Internship',
#  'Photovoice',
#  'Remittance',
#  'Field trip',
#  'Youth work',
#  'Policy mix',
#  'Unit price',
#  'Panel data',
#  'Choice set',
#  'Risk model',
#  'Estimation',
#  'Generality',
#  'Supervisor',
#  'Delegation',
#  'Scratching',
#  'Expediting',
#  'Time limit',
#  'Solid body',
#  'Strategist',
#  'Onboarding',
#  'Preference',
#  'Signalling',
#  'Total cost',
#  'Fixed cost',
#  'Sunk costs',
#  'Cheap talk',
#  'Free entry',
#  'Tax reform',
#  'Status quo',
#  'Free trade',
#  'Income tax',
#  'Mutual aid',
#  'Purchasing',
#  'Bottleneck',
#  'Spare part',
#  'Root cause',
#  'Day to day',
#  'Spare time',
#  'Work shift',
#  'Unbundling',
#  'Firm offer',
#  'Safe haven',
#  'Third wave',
#  'Free world',
#  'Low income',
#  'Gender gap',
#  'Land value',
#  'Urban area',
#  'Tax credit',
#  'Fair share',
#  'Free press',
#  'Rescission',
#  'Inner city',
#  'Geographer',
#  'Sick leave',
#  'Labour law',
#  'Pay Equity',
#  'Retraining',
#  'Fair trade',
#  'Suez canal',
#  'Small arms',
#  'Deductible',
#  'Death toll',
#  'North east',
#  'Chiang mai',
#  'Small town',
#  'Land price',
#  'Adam smith',
#  'Praxeology',
#  'Free state',
#  'Gilded Age',
#  'Opting out',
#  'Life value',
#  'Order book',
#  'Capitation',
#  'Book value',
#  'Debt ratio',
#  'PEGylation',
#  'Unit trust',
#  'Subsidiary',
#  'Model risk',
#  'Output gap',
#  'Eurodollar',
#  'Price risk',
#  'Basis risk',
#  'List price',
#  'Heliconius',
#  'Lycaenidae',
#  'Direct tax',
#  'Acute care',
#  'Adult care',
#  'AP Biology',
#  'Real wages',
#  'Final good',
#  'Monetarism',
#  'Fiat money',
#  'Indexation',
#  'Energy tax',
#  'Event data',
#  'Job stress',
#  'Audit risk',
#  'Leadership',
#  'Piece work',
#  'Net profit',
#  'Tax policy',
#  'Bulk queue',
#  'Work hours',
#  'Debit card',
#  'Short rate',
#  'Estate tax',
#  'Tax treaty',
#  'Telehealth',
#  'Prewriting',
#  'Wage share',
#  "Okun's law",
#  'Job design',
#  'Kano model',
#  'Mobile QoS',
#  'Index fund',
#  'Chargeback',
#  'Option fee',
#  'Health law',
#  'Job shadow',
#  'Audit plan',
#  'Metagaming',
#  'Tax shield',
#  'View model',
#  'Accounting',
#  'Commission',
#  'Bankruptcy',
#  'Collateral',
#  'Hedge fund',
#  'Divestment',
#  'Insolvency',
#  'Fair value',
#  'Net income',
#  'Prospectus',
#  'Contrarian',
#  'Seed money',
#  'For profit',
#  'Put option',
#  'Perpetuity',
#  'Face value',
#  'Rebranding',
#  'Trust fund',
#  'Legal risk',
#  'Purchasing',
#  'Spare part',
#  'Web survey',
#  'Strategist',
#  'Best value',
#  'Work order',
#  'Total cost',
#  'Fixed cost',
#  'Unbundling',
#  'Free entry',
#  'Firm offer',
#  'Risk model',
#  'Journalism',
#  'Mass media',
#  'News media',
#  'Impression',
#  'Legibility',
#  'Prime time',
#  'Title page',
#  'Box office',
#  'Typography',
#  'Storyboard',
#  'Mail order',
#  'Free trade',
#  'Retraining',
#  'Fair trade',
#  'Suez canal',
#  'Small arms',
#  'Free world',
#  'Deductible',
#  'Non profit',
#  'Order book',
#  'Capitation',
#  'Book value',
#  'Debt ratio',
#  'PEGylation',
#  'Unit trust',
#  'Subsidiary',
#  'Model risk',
#  'Output gap',
#  'Eurodollar',
#  'Price risk',
#  'Basis risk',
#  'List price',
#  'Heliconius',
#  'Lycaenidae',
#  'Direct tax',
#  'Bulk queue',
#  'Fiber crop',
#  'Leaf miner',
#  'Offshoring',
#  'Insourcing',
#  'Audit risk',
#  'Debit card',
#  'Short rate',
#  'Estate tax',
#  'Tax treaty',
#  'Kano model',
#  'Mobile QoS',
#  'Psylloidea',
#  'Bactrocera',
#  'Rhagoletis',
#  'Anastrepha',
#  'Index fund',
#  'Chargeback',
#  'Option fee',
#  'View model',
#  'Audit plan',
#  'Corporation',
#  'Structuring',
#  'Real estate',
#  'Credit risk',
#  'Discounting',
#  'Speculation',
#  'Mutual fund',
#  'Bond market',
#  'Beneficiary',
#  'Market risk',
#  'Fiscal year',
#  'Reinsurance',
#  'Bank credit',
#  'Foreclosure',
#  'Call option',
#  'Added value',
#  'Stress test',
#  'Home equity',
#  'Forbearance',
#  'Market data',
#  'Bookkeeping',
#  'Fungibility',
#  'Life skills',
#  'Health care',
#  'Scholarship',
#  'Empowerment',
#  'Social work',
#  'Brain drain',
#  'School meal',
#  'Living wage',
#  'Timor leste',
#  'Study guide',
#  'Mine action',
#  'Tax revenue',
#  'Price level',
#  'Price index',
#  'Demand side',
#  'Macro level',
#  'Value added',
#  'Supply side',
#  'Optimal tax',
#  'Medium term',
#  'Slow growth',
#  'New economy',
#  'Factor cost',
#  'Fresh Start',
#  'Job hunting',
#  'Endogeneity',
#  'Tobit model',
#  'House price',
#  'Data series',
#  'Stakeholder',
#  'Procurement',
#  'Absenteeism',
#  'Photography',
#  'Action plan',
#  'Proactivity',
#  'Human error',
#  'Fire safety',
#  'Deliverable',
#  'Soft skills',
#  'Discography',
#  'Social risk',
#  'Team leader',
#  'Career path',
#  'Human voice',
#  'Megaproject',
#  'Safety case',
#  'Gantt chart',
#  'Master plan',
#  'Work safety',
#  'Game theory',
#  'Externality',
#  'Public good',
#  'Social cost',
#  'Satisficing',
#  'Search cost',
#  'Veblen good',
#  'Global game',
#  'Market game',
#  'Cost driver',
#  'Paternalism',
#  'Opportunism',
#  'Consumerism',
#  'Meritocracy',
#  'State owned',
#  'Gun control',
#  'Flexicurity',
#  'Home market',
#  'Grey market',
#  'Cycle count',
#  'Workmanship',
#  'Drug prices',
#  'Price shock',
#  'Power index',
#  'Blue collar',
#  'Conurbation',
#  'City region',
#  'Energy cost',
#  'Tax evasion',
#  'Public fund',
#  'Third world',
#  'Urban space',
#  'Megalopolis',
#  'Trade union',
#  'Male female',
#  'Labor union',
#  'World trade',
#  'Risk theory',
#  'Subrogation',
#  'Family life',
#  'West bengal',
#  'North india',
#  'Food supply',
#  'Grain trade',
#  'Market size',
#  'Market rate',
#  'Shareholder',
#  'Long memory',
#  'Brent Crude',
#  'Credit card',
#  'Debt crisis',
#  'Seigniorage',
#  'Equity risk',
#  'Devaluation',
#  'Broad money',
#  'Yield curve',
#  'Basis point',
#  'Green paper',
#  'Share price',
#  'Nymphalidae',
#  'SMS banking',
#  'Gift giving',
#  'Year-ending',
#  'Health plan',
#  'Home health',
#  'Face shield',
#  'Health data',
#  'Shared care',
#  'Free clinic',
#  'ADDIE Model',
#  'Basic needs',
#  'Poor people',
#  'Poor relief',
#  'Stagflation',
#  'Payroll tax',
#  'Kwashiorkor',
#  'Work abroad',
#  'Fixed asset',
#  'Farm income',
#  'Limit price',
#  'Engel curve',
#  'Vine copula',
#  'Normal good',
#  'Ruin theory',
#  'Coreference',
#  "Fitts's law",
#  'Audit trail',
#  'Chaotic map',
#  'Spike train',
#  'Direct cost',
#  'Cost centre',
#  'Sonata form',
#  'Harpsichord',
#  'Free riding',
#  'Coopetition',
#  'Federal law',
#  'Profit rate',
#  'Micro level',
#  'Food stamps',
#  'Block grant',
#  'Test vector',
#  'Wage growth',
#  'Hourly wage',
#  'New england',
#  'Gig economy',
#  'Baton rouge',
#  'Ho chi minh',
#  'Paratransit',
#  'First World',
#  'Marie curie',
#  'Agency cost',
#  'Kerr metric',
#  'Black brane',
#  'Bridge loan',
#  'Tort reform',
#  'Pairs trade',
#  'Open outcry',
#  'Taylor rule',
#  'Object code',
#  'Joint audit',
#  'Sudden stop',
#  'Income fund',
#  'Feeder fund',
#  'Senior debt',
#  'Job costing',
#  'Bid shading',
#  'Advertising',
#  'Corporation',
#  'Structuring',
#  'Real estate',
#  'Credit risk',
#  'Discounting',
#  'Speculation',
#  'Mutual fund',
#  'Bond market',
#  'Beneficiary',
#  'Market risk',
#  'Fiscal year',
#  'Reinsurance',
#  'Bank credit',
#  'Foreclosure',
#  'Call option',
#  'Added value',
#  'Stress test',
#  'Home equity',
#  'Forbearance',
#  'Market data',
#  'Bookkeeping',
#  'Fungibility',
#  'Focus group',
#  'Outsourcing',
#  'Procurement',
#  'Co-creation',
#  'Brand image',
#  'Brand names',
#  'Cost driver',
#  'Consumables',
#  'Testimonial',
#  'Store brand',
#  'Sales force',
#  'Cycle count',
#  'Omnichannel',
#  'Consignment',
#  'Hypermarket',
#  'Direct mail',
#  'Requisition',
#  'Coffee shop',
#  'Double loop',
#  'Human error',
#  'Fire safety',
#  'Social risk',
#  'Safety case',
#  'Work safety',
#  'Publication',
#  'Gatekeeping',
#  ...]

# %%
nodes_of_management = [(item, G.nodes[item]['level']) for item in subgraph_nodes]
nodes_of_management = sorted(nodes_of_management, key=lambda x:x[1])

with open('D:\SciMig\concepts/concepts_Management_l.json', 'w') as fp:
    json.dump(subgraph_nodes, fp)

# %%
print(len(nodes_of_management))
level_count = dict()
for item in nodes_of_management:
    level_count[item[1]] = level_count.get(item[1], 0) + 1
print(level_count)
# Out:
# 6590
# {0: 2, 1: 53, 2: 2566, 3: 2572, 4: 861, 5: 536}

# %%
selected_management_concepts = []
for item in nodes_of_management:
    if item[1] == 1:
        selected_management_concepts.append(item)
    # level_count[item[1]] = level_count.get(item[1], 0) + 1
print(*selected_management_concepts, sep='\n')
# Out:
# ('Finance', 1)
# ('Economic growth', 1)
# ('Macroeconomics', 1)
# ('Econometrics', 1)
# ('Management', 1)
# ('Microeconomics', 1)
# ('Accounting', 1)
# ('Market economy', 1)
# ('Operations management', 1)
# ('Industrial organization', 1)
# ('Environmental resource management', 1)
# ('Monetary economics', 1)
# ('Mathematical economics', 1)
# ('Management science', 1)
# ('Financial economics', 1)
# ('Political economy', 1)
# ('Demographic economics', 1)
# ('Natural resource economics', 1)
# ('Economy', 1)
# ('Environmental economics', 1)
# ('Public economics', 1)
# ('Development economics', 1)
# ('Law and economics', 1)
# ('Economic geography', 1)
# ('Labour economics', 1)
# ('International trade', 1)
# ('Positive economics', 1)
# ('Actuarial science', 1)
# ('Economic system', 1)
# ('Socioeconomics', 1)
# ('Agricultural economics', 1)
# ('International economics', 1)
# ('Financial system', 1)
# ('Neoclassical economics', 1)
# ('Economic history', 1)
# ('Economic policy', 1)
# ('Keynesian economics', 1)
# ('Commerce', 1)
# ('Welfare economics', 1)
# ('Classical economics', 1)
# ('Finance', 1)
# ('Marketing', 1)
# ('Accounting', 1)
# ('Industrial organization', 1)
# ('Process management', 1)
# ('Risk analysis (engineering)', 1)
# ('Advertising', 1)
# ('International trade', 1)
# ('Actuarial science', 1)
# ('Financial system', 1)
# ('Economic policy', 1)
# ('Commerce', 1)
# ('Business administration', 1)

# %% [markdown]
# ## 测试concept读取

# %%
##
import json
with open('D:\SciMig\concepts/concepts_Medicine_l.json', 'r') as fp:
    physic_concept = json.load(fp)

# %%
len(set(physic_concept_2))
# Out:
# 18426

# %%
physic_concept_2 = [item[0].lower() for item in physic_concept]
sorted(physic_concept_2,key=len)
# Out:
# ['l1',
#  'sed',
#  'yak',
#  'nop',
#  'd-1',
#  'u87',
#  'cd5',
#  'rod',
#  'nod',
#  'cd8',
#  'q10',
#  'erg',
#  'abl',
#  'syk',
#  'fyn',
#  'lyn',
#  'e2f',
#  'apx',
#  'cd3',
#  'iif',
#  'ns3',
#  'hbx',
#  'p3a',
#  'p3b',
#  'nls',
#  'bus',
#  'cd1',
#  'lung',
#  'copd',
#  'meal',
#  'cats',
#  'vein',
#  'rash',
#  'dose',
#  'gout',
#  'pons',
#  'toad',
#  'mole',
#  'pco2',
#  'rana',
#  'sss*',
#  'peri',
#  'tasa',
#  'cyst',
#  'lobe',
#  'toll',
#  'dept',
#  'deet',
#  'nose',
#  'cord',
#  'cuff',
#  'ulna',
#  'anus',
#  'pacu',
#  'limp',
#  'stab',
#  'drug',
#  'mood',
#  'mdma',
#  'tics',
#  'cbcl',
#  'oxon',
#  'kava',
#  'khat',
#  'coca',
#  'slug',
#  'pill',
#  'axon',
#  'heel',
#  'club',
#  'chin',
#  'loin',
#  'hoof',
#  'spur',
#  'rump',
#  'fist',
#  'hock',
#  'tick',
#  'diva',
#  'gait',
#  'hook',
#  'acne',
#  'prom',
#  'twig',
#  'herd',
#  'ovis',
#  'flea',
#  'zebu',
#  'tlr4',
#  'cd14',
#  'smad',
#  'cd36',
#  'erbb',
#  'ed50',
#  'cd47',
#  'cd64',
#  'muc1',
#  'bmi1',
#  'bap1',
#  'ptx3',
#  'slpi',
#  'chop',
#  'nefa',
#  'scad',
#  'ards',
#  'cd20',
#  'cd31',
#  'cd68',
#  'hccs',
#  'neun',
#  'cd30',
#  'odds',
#  'egta',
#  'romk',
#  'pedf',
#  'cmax',
#  'adme',
#  'hl60',
#  'gist',
#  'kt/v',
#  'lama',
#  'sgk1',
#  'hamd',
#  'aura',
#  'herg',
#  'cd19',
#  'bufo',
#  'hoax',
#  'dapi',
#  'cypa',
#  'uvea',
#  'mand',
#  'dass',
#  'mews',
#  'vole',
#  'slum',
#  'boar',
#  'pmut',
#  'herb',
#  'milt',
#  'pusa',
#  'tlr2',
#  'aim2',
#  'nod2',
#  'irf3',
#  'irf7',
#  'ctgf',
#  'ccl2',
#  'grb2',
#  'gas6',
#  'ddr1',
#  'cd18',
#  'gpvi',
#  'npc1',
#  'fgf8',
#  'fgf9',
#  'hes1',
#  'jag1',
#  'trpc',
#  'ryr1',
#  'ibmx',
#  'dab1',
#  'mptp',
#  'sod1',
#  'gerd',
#  'prnp',
#  'smn1',
#  'vp40',
#  'trab',
#  'pkd1',
#  'cd24',
#  'kras',
#  'lgr5',
#  'e2f1',
#  'plk1',
#  'mmp2',
#  'rhoc',
#  'dmba',
#  'pca3',
#  'ros1',
#  'mdmx',
#  'wwox',
#  'iκbα',
#  'hamp',
#  'men1',
#  'atf6',
#  'atf4',
#  'pdx1',
#  'snf3',
#  'cidi',
#  'timi',
#  'mace',
#  'sod2',
#  'nox4',
#  'nox1',
#  'nfat',
#  'cd52',
#  'cd99',
#  'cd22',
#  'cd43',
#  'npr1',
#  'npr2',
#  'sobp',
#  'enos',
#  'nos1',
#  'cmin',
#  'myod',
#  'phex',
#  'ehna',
#  'liga',
#  'coix',
#  'inha',
#  'rpob',
#  'dhps',
#  'druj',
#  'cd28',
#  'cd86',
#  'btla',
#  'ctl*',
#  'cd46',
#  'cd59',
#  'ic3b',
#  'gp41',
#  'pax5',
#  'cd23',
#  'lyme',
#  'sida',
#  'zona',
#  'cd81',
#  'dmp1',
#  'n400',
#  'n100',
#  'n2pc',
#  'lida',
#  'lmna',
#  'rapd',
#  'tlr7',
#  'tlr3',
#  'trif',
#  'tlr5',
#  'irf5',
#  'nod1',
#  'acpd',
#  'ccpa',
#  'cnqx',
#  'nbqx',
#  'dnqx',
#  'tph2',
#  'ptk2',
#  'ror1',
#  'ccr2',
#  'ccr1',
#  'ccl7',
#  'ccr3',
#  'xcl2',
#  'ccr4',
#  'ccl3',
#  'ctbs',
#  'rgs2',
#  'fgf1',
#  'syt1',
#  'trpv',
#  'nerd',
#  'kuru',
#  'gper',
#  'hras',
#  'msh6',
#  'mlh1',
#  'msh2',
#  'pms2',
#  'ask1',
#  'mad2',
#  'wee1',
#  'dnaa',
#  'fhit',
#  'rnf4',
#  'ighd',
#  'dio2',
#  'abvd',
#  'irs2',
#  'irs1',
#  'ucp3',
#  'gpx4',
#  'gpx1',
#  'gpx3',
#  'gpx6',
#  'dlco',
#  'dnag',
#  'pkm2',
#  'lrp1',
#  'frax',
#  'myf5',
#  'per2',
#  'per1',
#  'cd1d',
#  'ccl5',
#  'cd69',
#  'cd74',
#  'cd16',
#  'bcl6',
#  'ns5a',
#  'ns5b',
#  'itpa',
#  'p600',
#  'snus',
#  'urine',
#  'stent',
#  'aorta',
#  'ovary',
#  'apnea',
#  'edema',
#  'ileum',
#  'liter',
#  'nodal',
#  'gonad',
#  'crypt',
#  'cecum',
#  'quail',
#  'sweat',
#  'ratón',
#  'ileus',
#  'enema',
#  'gdf15',
#  'ankle',
#  'lymph',
#  'mucin',
#  'scars',
#  'vulva',
#  'spots',
#  'morin',
#  'snuff',
#  'cutis',
#  'tempe',
#  'milia',
#  'harem',
#  'labia',
#  'virus',
#  'lysis',
#  'tears',
#  'femur',
#  'elbow',
#  'skull',
#  'wrist',
#  'tibia',
#  'scalp',
#  'blunt',
#  'thumb',
#  'penis',
#  'thigh',
#  'groin',
#  'pouch',
#  'lasik',
#  'clips',
#  'bleed',
#  'cheek',
#  'fossa',
#  'foley',
#  'pinna',
#  'navel',
#  'galea',
#  'atony',
#  'juxta',
#  'hasta',
#  'anger',
#  'blame',
#  'grief',
#  'dsm-5',
#  'idiot',
#  'vinca',
#  'semen',
#  'torso',
#  'melon',
#  'flank',
#  'calyx',
#  'flake',
#  'snout',
#  'conus',
#  'zooid',
#  'manus',
#  'platy',
#  'vomer',
#  'croup',
#  'spins',
#  'voxel',
#  'gyrus',
#  'lying',
#  'dicom',
#  'squat',
#  'molar',
#  'inlay',
#  'hyrax',
#  'globe',
#  'piper',
#  'senna',
#  'vitex',
#  'khaya',
#  'sperm',
#  'flock',
#  'mange',
#  'hmgb1',
#  'stat1',
#  'stat5',
#  'decoy',
#  'bapta',
#  'nf-κb',
#  'theca',
#  'waist',
#  'islet',
#  'ki-67',
#  'stim1',
#  'atopy',
#  'hif1a',
#  'itga7',
#  'chyle',
#  'bcl10',
#  'tgfbi',
#  'toeic',
#  'felis',
#  'myoma',
#  'cavia',
#  'palsy',
#  'kampo',
#  'stain',
#  'eosin',
#  'aedes',
#  'umami',
#  'udder',
#  'hnf1a',
#  'foxp3',
#  'titer',
#  'alcam',
#  'hymen',
#  'glans',
#  'worry',
#  'panic',
#  'ictal',
#  'lamin',
#  'ursus',
#  'wader',
#  'nevus',
#  'adept',
#  'bruit',
#  'kerma',
#  'azole',
#  'sepia',
#  'rig-i',
#  'nalp3',
#  'ccl18',
#  'ppads',
#  'cxcr4',
#  'cxcl1',
#  'cxcl5',
#  'cd135',
#  'rankl',
#  'erbb3',
#  'erbb4',
#  'mertk',
#  'trpc1',
#  'trpv4',
#  'trpm7',
#  'agrin',
#  'escrt',
#  'lamp1',
#  'adcy9',
#  'fgf21',
#  'fgf10',
#  'fgf19',
#  'fkbp5',
#  'trpv1',
#  'trpc6',
#  'trpv6',
#  'trpm2',
#  'kinin',
#  'c-met',
#  'supar',
#  'traf2',
#  'trem2',
#  'lrrk2',
#  'sf-36',
#  'eq-5d',
#  'foxa1',
#  'foxm1',
#  'lncap',
#  'tramp',
#  'pd-l1',
#  'tigit',
#  'cd137',
#  'socs3',
#  'socs2',
#  'socs6',
#  'glut4',
#  'glut1',
#  'glut2',
#  'p2y12',
#  'tbars',
#  'txnip',
#  'stat6',
#  'orai1',
#  'cyp3a',
#  'mania',
#  'ighv@',
#  'c2c12',
#  'varix',
#  'titin',
#  'clock',
#  'gata1',
#  'mg132',
#  'δf508',
#  'equol',
#  'womac',
#  'kudzu',
#  'inula',
#  'hrhis',
#  'calla',
#  'hbsag',
#  'hla-g',
#  'hla-a',
#  'hla-b',
#  'hla-c',
#  'incus',
#  'upgma',
#  'alien',
#  'opsin',
#  'rpe65',
#  'gpr18',
#  'am251',
#  'damgo',
#  'dadle',
#  'raphe',
#  'mapk7',
#  'pdgfb',
#  'cyr61',
#  'ccl21',
#  'cxcr3',
#  'ccl13',
#  'cxcl2',
#  'ccl17',
#  'cxcr5',
#  'ccl20',
#  'cxcl9',
#  'ccl19',
#  'ccr10',
#  'ccl22',
#  'ccl25',
#  'ccl11',
#  'cd11a',
#  'cd49c',
#  'trpc5',
#  't790m',
#  'adcy6',
#  'adcy3',
#  'nlrc4',
#  'trpm8',
#  'trpc3',
#  'psen1',
#  'pink1',
#  'panca',
#  'basfi',
#  'mcf-7',
#  'skbr3',
#  'stk11',
#  'sn-38',
#  'c-raf',
#  'prkcq',
#  'chek1',
#  'cdc25',
#  'cdc20',
#  'snai1',
#  'du145',
#  'socs5',
#  'gnrhr',
#  'olig2',
#  'mesna',
#  'grb10',
#  'glut3',
#  'iebus',
#  'pcsk9',
#  'kexin',
#  'lrp1b',
#  'stx1a',
#  'ivivc',
#  's1pr1',
#  'zap70',
#  'nk-92',
#  'cd49b',
#  'ciita',
#  'bzlf1',
#  'hbeag',
#  'hbcag',
#  'cancer',
#  'cohort',
#  'kidney',
#  'asthma',
#  'biopsy',
#  'artery',
#  'sepsis',
#  'spleen',
#  'anemia',
#  'rhythm',
#  'saline',
#  'reflex',
#  'nausea',
#  'dosing',
#  'uterus',
#  'rectum',
#  'saliva',
#  'ageing',
#  'statin',
#  'uremia',
#  'baboon',
#  'niacin',
#  'beagle',
#  'chills',
#  'thirst',
#  'libido',
#  'caecum',
#  'ostium',
#  'myxoma',
#  'osmole',
#  'pallor',
#  'melena',
#  'anuria',
#  'tetany',
#  't-maze',
#  'kowsar',
#  'bezoar',
#  'suncus',
#  'suidae',
#  'lesion',
#  'tendon',
#  'dentin',
#  'flavor',
#  'tongue',
#  'dermis',
#  'gluten',
#  'rabies',
#  'atypia',
#  'fascia',
#  'lipoma',
#  'tonsil',
#  'keloid',
#  'toilet',
#  'eschar',
#  'areola',
#  'tunica',
#  'hickey',
#  'ranula',
#  'epulis',
#  'yankee',
#  'lectin',
#  'fibrin',
#  'pandas',
#  'elafin',
#  'lumbar',
#  'airway',
#  'larynx',
#  'hernia',
#  'pelvis',
#  'vagina',
#  'biceps',
#  'otitis',
#  'eyelid',
#  'ureter',
#  'valgus',
#  'sulcus',
#  'throat',
#  'plexus',
#  'sclera',
#  'sacrum',
#  'ptosis',
#  'rachis',
#  'medius',
#  'meatus',
#  'stylet',
#  'bloody',
#  'bruise',
#  'autism',
#  'neuron',
#  'ataxia',
#  'triage',
#  'crying',
#  'icd-10',
#  'datura',
#  'retard',
#  'mucuna',
#  'sanity',
#  'glioma',
#  'crocin',
#  'lotion',
#  'curare',
#  'miosis',
#  'dorsum',
#  'lamina',
#  'crania',
#  'coelom',
#  'sucker',
#  'cloaca',
#  'temple',
#  'nasion',
#  'conoid',
#  'coffin',
#  'agatha',
#  'typhus',
#  'slider',
#  'heliox',
#  'sprint',
#  'crunch',
#  'stride',
#  'veneer',
#  'gating',
#  'cornea',
#  'ocimum',
#  'punica',
#  'salvia',
#  'ginkgo',
#  'lupeol',
#  'croton',
#  'nutmeg',
#  'crocus',
#  'siddha',
#  'grewia',
#  'opioid',
#  'opiate',
#  'ephrin',
#  'reelin',
#  'apelin',
#  'siglec',
#  'reflux',
#  'apathy',
#  'chorea',
#  'cervix',
#  'cdkn2a',
#  's100a9',
#  's100a8',
#  'myelin',
#  'leptin',
#  'angina',
#  'stroma',
#  'fascin',
#  'hmb-45',
#  'apamin',
#  'sterol',
#  'tubule',
#  'klotho',
#  'fornix',
#  'gerbil',
#  'wheeze',
#  'nonmem',
#  'p wave',
#  'seroma',
#  'pyuria',
#  'goiter',
#  'pannus',
#  'venule',
#  'acinus',
#  'antrum',
#  'globin',
#  'stupor',
#  'kitten',
#  't wave',
#  'j wave',
#  'u wave',
#  'scurvy',
#  'torpor',
#  'corrin',
#  'orgasm',
#  'f wave',
#  'peptic',
#  'occult',
#  'lycium',
#  'stevia',
#  'papule',
#  'sputum',
#  'orcein',
#  'glomus',
#  'osteon',
#  'ht1080',
#  't cell',
#  'balb/c',
#  'b cell',
#  'hapten',
#  'capsid',
#  'simian',
#  'hla-dr',
#  'taenia',
#  'icam-1',
#  'ixodes',
#  'dispar',
#  'lunate',
#  'physis',
#  'calcar',
#  'pet-ct',
#  'clivus',
#  'fibula',
#  'labrum',
#  'vicryl',
#  'stapes',
#  'coccyx',
#  'lexico',
#  'cinahl',
#  'heroin',
#  'clonus',
#  'drusen',
#  'dyrk1a',
#  'census',
#  'fledge',
#  'flyway',
#  'f-test',
#  'branta',
#  'chaeta',
#  'gamete',
#  'ferula',
#  'foveal',
#  'nepeta',
#  'annona',
#  'stover',
#  'igfbp3',
#  'cxcl10',
#  'orexin',
#  'gpr120',
#  'netrin',
#  'plexin',
#  'acvr2b',
#  'sema3a',
#  'cyp8b1',
#  'reeler',
#  'parkin',
#  'basdai',
#  'scorad',
#  'axilla',
#  'taxane',
#  'ca15-3',
#  'cyclin',
#  'maspin',
#  'ca19-9',
#  'cdkn2b',
#  'taxoid',
#  'dipper',
#  'tectum',
#  'prdm16',
#  'amylin',
#  'trolox',
#  'desmin',
#  'meddra',
#  'cav1.2',
#  'cyp3a4',
#  'cyp1a2',
#  'cyp2d6',
#  'cyp2c9',
#  'cyp2e1',
#  'cyp1b1',
#  'apobec',
#  'g cell',
#  '3t3-l1',
#  'pdgfra',
#  'tophus',
#  'nocebo',
#  'cassia',
#  'phlegm',
#  'coptis',
#  'bombyx',
#  'lobata',
#  'toxoid',
#  'esat-6',
#  'ctla-4',
#  'dander',
#  'viroid',
#  'mottle',
#  'condom',
#  'vcam-1',
#  'tympan',
#  'n-back',
#  'cuneus',
#  'r-smad',
#  'cx3cr1',
#  'cxcl16',
#  'cxcl14',
#  'cx3cl1',
#  'cxcl13',
#  'cxcl11',
#  'piezo1',
#  'rs6265',
#  'adcy10',
#  'gucy2d',
#  'gabbr1',
#  'curfew',
#  'tardbp',
#  'pelp-1',
#  'comedo',
#  'ptpn11',
#  'folfox',
#  'map2k7',
#  'mapk14',
#  'map3k7',
#  'cdc25a',
#  'gadd45',
#  'p14arf',
#  'thrush',
#  'cyp2b6',
#  'cyp2a6',
#  'cyp2c8',
#  'vkorc1',
#  'adamts',
#  'adam10',
#  'tcirg1',
#  'cccdna',
#  'essure',
#  'surgery',
#  'anatomy',
#  'nursing',
#  'urology',
#  'disease',
#  'hormone',
#  'obesity',
#  'insulin',
#  'calcium',
#  'thyroid',
#  'myocyte',
#  'regimen',
#  'vitamin',
#  'stomach',
#  'atrophy',
#  'myeloid',
#  'aspirin',
#  'heparin',
#  'albumin',
#  'autopsy',
#  'colitis',
#  'morning',
#  'adenoma',
#  'hamster',
#  'balloon',
#  'weaning',
#  'calorie',
#  'putamen',
#  'ascites',
#  'choline',
#  'group b',
#  'wasting',
#  'jejunum',
#  'medulla',
#  'myalgia',
#  'atresia',
#  'group a',
#  'oviduct',
#  'bedtime',
#  'el niño',
#  'reentry',
#  'licking',
#  'osteoid',
#  'd-dimer',
#  'washout',
#  'dilator',
#  'malaise',
#  'ectasia',
#  'aplasia',
#  'ampulla',
#  'embolus',
#  'motilin',
#  'c57bl/6',
#  'antacid',
#  'work-up',
#  'zeranol',
#  'truncus',
#  'cerebro',
#  'malaria',
#  'sarcoma',
#  'forearm',
#  'hygiene',
#  'sitting',
#  'elastin',
#  'keratin',
#  'gliosis',
#  'cholera',
#  'leprosy',
#  'biocide',
#  'exudate',
#  'hyaline',
#  'thymoma',
#  'empyema',
#  'lagging',
#  'babesia',
#  'bathing',
#  'adenoid',
#  'fibroma',
#  'shampoo',
#  'borough',
#  'asepsis',
#  'otology',
#  'green s',
#  'safrole',
#  'earlobe',
#  'curette',
#  'lawsone',
#  'urachus',
#  'antigen',
#  'allergy',
#  'uveitis',
#  'mycosis',
#  'itching',
#  ...]

# %%
import json
with open('D:\SciMig\concepts/concepts_Management_l.json', 'r') as fp:
    mana_concept = json.load(fp)

# %%
len(set(mana_concept))
# Out:
# 4810

# %% [markdown]
# test merged_author_id

# %%
# 简单统计下5开头的和非5开头的author数量
from utils import scan_list, extract_certain_suffix
import pandas as pd
fl = extract_certain_suffix(scan_list('merged_authors'), 'txt')

start_with_5_count = 0
start_with_else_count = 0
for fpath in fl:
    df = pd.read_csv(fpath, header=0)
    ids = df['id'].tolist() + df['merge_into_id'].tolist()
    for one_id in ids:
        if one_id[1] == '5':
            start_with_5_count += 1
        else:
            start_with_else_count += 1

print(start_with_5_count, start_with_else_count)
# Out:
# 7376100 0

# %% [markdown]
# # 测试按照 source 寻找 work 的方法

# %%
import json

test_snapshot_fp = r'works\updated_date=2024-02-15\part_000.txt'
c = 10000
type_set = set()
with open(test_snapshot_fp, 'r', encoding='utf-8') as fp:
    for line in fp:
        json_obj = json.loads(line)
        w_type = json_obj['type_crossref']
        type_set.add(w_type)
        c -= 1
        if c < 0:
            break

# %%
type_set
# Out:
# {'book',
#  'book-chapter',
#  'dataset',
#  'dissertation',
#  'edited-book',
#  'journal',
#  'journal-article',
#  'journal-issue',
#  'monograph',
#  'other',
#  'posted-content',
#  'proceedings-article',
#  'report'}

# %%
json_obj.keys()
# Out:
# dict_keys(['id', 'doi', 'doi_registration_agency', 'display_name', 'title', 'publication_year', 'publication_date', 'language', 'ids', 'primary_location', 'best_oa_location', 'type', 'type_crossref', 'open_access', 'authorships', 'countries_distinct_count', 'institutions_distinct_count', 'corresponding_author_ids', 'corresponding_institution_ids', 'cited_by_count', 'summary_stats', 'biblio', 'is_retracted', 'is_paratext', 'concepts', 'mesh', 'locations_count', 'locations', 'referenced_works', 'referenced_works_count', 'sustainable_development_goals', 'keywords', 'grants', 'apc_list', 'apc_paid', 'cited_by_percentile_year', 'related_works', 'abstract_inverted_index', 'counts_by_year', 'cited_by_api_url', 'updated_date', 'created_date', 'updated', 'authors_count', 'concepts_count', 'has_fulltext'])

# %%
json_obj['primary_location']['source']['display_name']
# Out:
# {'id': 'https://openalex.org/S4306463673',
#  'issn_l': None,
#  'issn': None,
#  'display_name': 'Nouveau Monde eBooks',
#  'publisher': 'Nouveau Monde',
#  'host_organization': None,
#  'host_organization_name': None,
#  'host_organization_lineage': [],
#  'host_organization_lineage_names': [],
#  'is_oa': False,
#  'is_in_doaj': False,
#  'host_institution_lineage': [],
#  'host_institution_lineage_names': [],
#  'publisher_lineage': [],
#  'publisher_lineage_names': [],
#  'publisher_id': None,
#  'type': 'ebook platform'}

# %%
# Out:
# 'book'

# %%
# 先统计各个source有多少数据

import pandas as pd

# %%
source_info = pd.read_excel(r'AI_Export\AI_sourceID.xlsx')
source_info = source_info.rename(columns={'Source ID': 'source_id'})
# print(source_info)

# %%
work_exported = pd.read_csv(r'AI_Export\works_AI_top_exported.csv', header=0)
# Out:
# C:\Users\xiongyuchen\AppData\Local\Temp\3\ipykernel_44160\3260097572.py:1: DtypeWarning: Columns (34,36,47,70,74,88,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   work_exported = pd.read_csv(r'AI_Export\works_AI_top_exported.csv', header=0)

# %%
work_exported.columns
# Out:
# Index(['id', 'display_name', 'publication_date', 'relevance_score',
#        'primary_location_id', 'primary_location_display_name',
#        'primary_location_host_organization', 'primary_location_issns',
#        'primary_location_issn_l', 'primary_location_type',
#        ...
#        'locations_is_oa', 'apc_paid_currency', 'primary_location_source_type',
#        'abstract', 'best_oa_location_is_published', 'best_oa_location',
#        'best_oa_location_source_type', 'locations_source',
#        'primary_location_source_host_organization_name',
#        'best_oa_location_source_host_organization_lineage'],
#       dtype='object', length=152)

# %%
work_exported['primary_location_id'].tolist()[:2]
# Out:
# ['https://openalex.org/S25538012', 'https://openalex.org/S4363606243']

# %%
stats = work_exported.groupby('primary_location_id').size().reset_index()
stats['primary_location_id'] = stats['primary_location_id'].apply(lambda x:x.replace('https://openalex.org/S', 's'))
stats = stats.rename(columns={'primary_location_id': 'source_id'})
stats.head(10)
source_info = pd.merge(source_info, stats, how='outer', on='source_id')

# %%
source_info.to_csv('AI_Export/work_count.csv')

# %%
# 提取顶刊作者集合

# %%
list(work_exported.columns)
# Out:
# ['id',
#  'display_name',
#  'publication_date',
#  'relevance_score',
#  'primary_location_id',
#  'primary_location_display_name',
#  'primary_location_host_organization',
#  'primary_location_issns',
#  'primary_location_issn_l',
#  'primary_location_type',
#  'primary_location_landing_page_url',
#  'primary_location_pdf_url',
#  'primary_location_is_oa',
#  'primary_location_version',
#  'primary_location_license',
#  'author_ids',
#  'author_names',
#  'author_orcids',
#  'author_institution_ids',
#  'author_institution_names',
#  'is_oa',
#  'oa_status',
#  'oa_url',
#  'cited_by_count',
#  'doi',
#  'mag',
#  'pmid',
#  'pmcid',
#  'publication_year',
#  'cited_by_api_url',
#  'type',
#  'is_paratext',
#  'is_retracted',
#  'biblio_issue',
#  'biblio_first_page',
#  'biblio_volume',
#  'biblio_last_page',
#  'referenced_works',
#  'related_works',
#  'concept_ids',
#  'best_oa_location_is_accepted',
#  'institutions_distinct_count',
#  'fulltext_origin',
#  'cited_by_percentile_year_max',
#  'apc_list_provenance',
#  'concepts_score',
#  'best_oa_location_source_host_organization_name',
#  'is_authors_truncated',
#  'primary_topic_id',
#  'mesh_qualifier_name',
#  'primary_topic_score',
#  'apc_paid_value',
#  'keywords_display_name',
#  'primary_location_source_host_organization_lineage_names',
#  'best_oa_location_source_issn_l',
#  'concepts_display_name',
#  'best_oa_location_source_host_organization',
#  'created_date',
#  'apc_paid_provenance',
#  'primary_location_source_host_organization_lineage',
#  'primary_location_source_is_in_doaj',
#  'primary_topic_display_name',
#  'apc_paid',
#  'primary_location_is_accepted',
#  'open_access_is_oa',
#  'language',
#  'primary_topic_field_id',
#  'primary_location_source_display_name',
#  'concepts_wikidata',
#  'best_oa_location_source_is_in_doaj',
#  'datasets',
#  'primary_topic_field_display_name',
#  'locations_pdf_url',
#  'locations_version',
#  'counts_by_year_year',
#  'best_oa_location_pdf_url',
#  'primary_topic',
#  'versions',
#  'best_oa_location_source_issn',
#  'mesh_is_major_topic',
#  'apc_list_currency',
#  'has_fulltext',
#  'locations_is_accepted',
#  'best_oa_location_source',
#  'sustainable_development_goals_score',
#  'best_oa_location_source_host_organization_lineage_names',
#  'apc_list_value_usd',
#  'keywords_id',
#  'counts_by_year_cited_by_count',
#  'best_oa_location_source_display_name',
#  'primary_topic_subfield_display_name',
#  'countries_distinct_count',
#  'mesh_descriptor_ui',
#  'title',
#  'primary_topic_domain_display_name',
#  'topics_id',
#  'locations_count',
#  'mesh_qualifier_ui',
#  'primary_topic_subfield_id',
#  'authorships_author_position',
#  'cited_by_percentile_year_min',
#  'indexed_in',
#  'primary_location_source_issn_l',
#  'best_oa_location_is_oa',
#  'best_oa_location_version',
#  'referenced_works_count',
#  'primary_location_source_issn',
#  'keywords_score',
#  'type_crossref',
#  'apc_list',
#  'best_oa_location_license',
#  'primary_location_source_is_oa',
#  'locations_is_published',
#  'topics_display_name',
#  'primary_location_source_id',
#  'ids_doi',
#  'mesh_descriptor_name',
#  'best_oa_location_source_is_oa',
#  'locations_landing_page_url',
#  'corresponding_author_ids',
#  'apc_paid_value_usd',
#  'open_access_any_repository_has_fulltext',
#  'sustainable_development_goals_id',
#  'authorships_is_corresponding',
#  'ngrams_url',
#  'primary_location_source_host_organization',
#  'grants_funder_display_name',
#  'best_oa_location_landing_page_url',
#  'locations_license',
#  'ids_openalex',
#  'corresponding_institution_ids',
#  'apc_list_value',
#  'sustainable_development_goals_display_name',
#  'best_oa_location_source_id',
#  'updated_date',
#  'grants_funder',
#  'topics_score',
#  'primary_location_is_published',
#  'concepts_id',
#  'grants_award_id',
#  'concepts_level',
#  'primary_topic_domain_id',
#  'locations_is_oa',
#  'apc_paid_currency',
#  'primary_location_source_type',
#  'abstract',
#  'best_oa_location_is_published',
#  'best_oa_location',
#  'best_oa_location_source_type',
#  'locations_source',
#  'primary_location_source_host_organization_name',
#  'best_oa_location_source_host_organization_lineage']

# %%
total_author_l = []
for item in work_exported['author_ids']:
    try:
        total_author_l += item.split('|')
    except AttributeError:  # 啊？ AttributeError: 'float' object has no attribute 'split'
        pass
        # print(item)

print(len(total_author_l))
print(len(set(total_author_l)))
# Out:
# 186224
# 78331

# %%
total_author_l[200:210]
# Out:
# ['https://openalex.org/A5062309861',
#  'https://openalex.org/A5047918353',
#  'https://openalex.org/A5031881955',
#  'https://openalex.org/A5039754725',
#  'https://openalex.org/A5067810758',
#  'https://openalex.org/A5028352869',
#  'https://openalex.org/A5021390142',
#  'https://openalex.org/A5049098969',
#  'https://openalex.org/A5037419606',
#  'https://openalex.org/A5036257681']

# %%
AI_author_df = pd.DataFrame({'author_id': total_author_l})

# %%
AI_author_df.to_csv('journal_author_ids_AI2.csv')

# %%
import pickle
with open(r'AI_Export\top_works.pkl', 'rb') as fp:
    s = list(pickle.load(fp))

# %%
print(len(s)) # 这个是raw的数据

# 仅仅是ID去重
clean_s_1 = set([item[0] for item in s])
print(len(clean_s_1))

# 去除掉 title 为空 的所有论文
clean_s_2 = list(set([item for item in s if item[2] != '']))
print(len(clean_s_2))
# Out:
# 105189
# 105189
# 104784

# %%
import pandas as pd
source_df = pd.DataFrame(clean_s_2, columns=['wid', 'sid', 'title'])
# source_df.head(5)
source_df_stats = source_df.groupby('sid').size().reset_index()
source_df_stats['sid'] = source_df_stats['sid'].apply(lambda x:x.replace('https://openalex.org/S', 's'))
source_df_stats.to_csv('temp_export_scount.csv')

# %%
# 怎么会一个title对应多个ID，我bk了
print(len(set([item[2] for item in clean_s_2])))
title2workid = dict()
for wid, sid, title in clean_s_2:
    if title in title2workid:
        title2workid[title].append((wid, sid))
    else:
        title2workid[title] = [(wid, sid)]

# 然后打印出来这些
for title, l in title2workid.items():
    if len(l) > 1:
        print(f'{title}, {l[0]}, {l[1]}')
# Out:
# 96389
# author index volume, ('https://openalex.org/W4232526348', 'https://openalex.org/S196139623'), ('https://openalex.org/W4243358307', 'https://openalex.org/S196139623')
# message from the general chairs, ('https://openalex.org/W4248213924', ''), ('https://openalex.org/W4239332213', '')
# nonmetric lens distortion calibration closed form solutions robust estimation and model selection, ('https://openalex.org/W2168987272', ''), ('https://openalex.org/W3139739645', '')
# the animation transformer visual correspondence via segment matching, ('https://openalex.org/W3198702899', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3204659518', '')
# none, ('https://openalex.org/W2133776599', 'https://openalex.org/S25538012'), ('https://openalex.org/W1883513582', 'https://openalex.org/S25538012')
# front cover, ('https://openalex.org/W4247244544', 'https://openalex.org/S199944782'), ('https://openalex.org/W4242802432', 'https://openalex.org/S199944782')
# distributed very large scale bundle adjustment by global camera consensus, ('https://openalex.org/W2779304298', ''), ('https://openalex.org/W2803297720', 'https://openalex.org/S199944782')
# automated reformulation of specifications by safe delay of constraints, ('https://openalex.org/W2109940223', 'https://openalex.org/S196139623'), ('https://openalex.org/W3010038845', 'https://openalex.org/S196139623')
# it s about time, ('https://openalex.org/W2043783734', ''), ('https://openalex.org/W4313438611', '')
# bitext maps and alignment via pattern recognition, ('https://openalex.org/W1497763703', 'https://openalex.org/S155526855'), ('https://openalex.org/W3148522895', 'https://openalex.org/S155526855')
# active and passive learning of linear separators under log concave distributions, ('https://openalex.org/W2516618844', 'https://openalex.org/S118988714'), ('https://openalex.org/W2963402790', '')
# image text retrieval a survey on recent research and development, ('https://openalex.org/W4225166070', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4221151300', 'https://openalex.org/S4363608755')
# message from general chairs, ('https://openalex.org/W4254502454', ''), ('https://openalex.org/W4244730233', '')
# feature mapping for learning fast and accurate d pose inference from synthetic images, ('https://openalex.org/W4307996960', ''), ('https://openalex.org/W2962956488', '')
# message from the program chairs, ('https://openalex.org/W4251854389', ''), ('https://openalex.org/W4233588746', '')
# control structures for software agents, ('https://openalex.org/W47378868', ''), ('https://openalex.org/W2915019373', '')
# inside front cover, ('https://openalex.org/W4205636336', 'https://openalex.org/S199944782'), ('https://openalex.org/W4249540694', 'https://openalex.org/S199944782')
# advances in neural information processing systems nips, ('https://openalex.org/W2597851033', ''), ('https://openalex.org/W2595840341', '')
# table of contents back cover, ('https://openalex.org/W4239621509', 'https://openalex.org/S199944782'), ('https://openalex.org/W4250965790', 'https://openalex.org/S199944782')
# conceptual analysis of garden path sentences, ('https://openalex.org/W2142476849', ''), ('https://openalex.org/W2888881302', '')
# publications received, ('https://openalex.org/W4242977050', 'https://openalex.org/S155526855'), ('https://openalex.org/W4254068042', 'https://openalex.org/S155526855')
# a case analysis method cooperating with atng and its application to machine translation, ('https://openalex.org/W2241519582', ''), ('https://openalex.org/W2889115929', '')
# declaration based prompt tuning for visual question answering, ('https://openalex.org/W4229069940', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285605365', 'https://openalex.org/S4363608755')
# the complexity landscape of decompositional parameters for ilp, ('https://openalex.org/W2782564847', 'https://openalex.org/S196139623'), ('https://openalex.org/W4289560513', 'https://openalex.org/S4210191458')
# message passing algorithms for quadratic minimization, ('https://openalex.org/W3087973312', 'https://openalex.org/S118988714'), ('https://openalex.org/W2155852402', 'https://openalex.org/S118988714')
# ieee computer society information, ('https://openalex.org/W4308422062', 'https://openalex.org/S199944782'), ('https://openalex.org/W4308422059', 'https://openalex.org/S199944782')
# learning when concepts abound, ('https://openalex.org/W3012549545', 'https://openalex.org/S118988714'), ('https://openalex.org/W2170674774', 'https://openalex.org/S118988714')
# efficient algorithms for universal portfolios, ('https://openalex.org/W2076798318', 'https://openalex.org/S118988714'), ('https://openalex.org/W3003346165', 'https://openalex.org/S118988714')
# bit mixer mixed precision networks with runtime bit width selection, ('https://openalex.org/W3147877189', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202614464', '')
# panel on natural language and databases, ('https://openalex.org/W2888810903', ''), ('https://openalex.org/W2205072740', '')
# message from program chairs, ('https://openalex.org/W4242009574', ''), ('https://openalex.org/W4237131914', '')
# call for papers for special issue on biometrics progress and directions, ('https://openalex.org/W4210278267', 'https://openalex.org/S199944782'), ('https://openalex.org/W4239453159', 'https://openalex.org/S199944782')
# message from the general chair, ('https://openalex.org/W4387011265', ''), ('https://openalex.org/W4243492199', '')
# multiple instance learning from distributions, ('https://openalex.org/W2520758021', 'https://openalex.org/S118988714'), ('https://openalex.org/W3007912632', 'https://openalex.org/S118988714')
# learning and inferring image segmentations using the gbp typical cut algorithm, ('https://openalex.org/W2097056524', ''), ('https://openalex.org/W3141717690', '')
# curiosity driven exploration by self supervised prediction, ('https://openalex.org/W2751973545', ''), ('https://openalex.org/W2963523627', '')
# approximating optimal social choice under metric preferences, ('https://openalex.org/W2886307781', 'https://openalex.org/S196139623'), ('https://openalex.org/W2398408548', 'https://openalex.org/S4210191458')
# nonparametric sparsity and regularization, ('https://openalex.org/W2998426454', 'https://openalex.org/S118988714'), ('https://openalex.org/W2107194942', 'https://openalex.org/S118988714')
# gan compression efficient architectures for interactive conditional gans, ('https://openalex.org/W4225547403', 'https://openalex.org/S199944782'), ('https://openalex.org/W3035204081', '')
# tpami information for authors, ('https://openalex.org/W4244675947', 'https://openalex.org/S199944782'), ('https://openalex.org/W4242565856', 'https://openalex.org/S199944782')
# subject index, ('https://openalex.org/W4235023915', 'https://openalex.org/S199944782'), ('https://openalex.org/W4243933766', 'https://openalex.org/S199944782')
# derivative estimation based on difference sequence via locally weighted least squares regression, ('https://openalex.org/W3144835850', 'https://openalex.org/S118988714'), ('https://openalex.org/W2275812670', '')
# table of contents, ('https://openalex.org/W4242100633', 'https://openalex.org/S199944782'), ('https://openalex.org/W4242459804', 'https://openalex.org/S199944782')
# an automatic procedure for topic focus identification, ('https://openalex.org/W3089147187', 'https://openalex.org/S155526855'), ('https://openalex.org/W1598926006', 'https://openalex.org/S155526855')
# dynamic policy programming with function approximation, ('https://openalex.org/W2130179125', ''), ('https://openalex.org/W2607023479', 'https://openalex.org/S118988714')
# symmetries and lazy clause generation, ('https://openalex.org/W2780136051', ''), ('https://openalex.org/W41781360', '')
# linear algorithms for online multitask classification, ('https://openalex.org/W2116772053', 'https://openalex.org/S118988714'), ('https://openalex.org/W3041171336', 'https://openalex.org/S118988714')
# weighted substructure mining for image analysis, ('https://openalex.org/W2520044360', ''), ('https://openalex.org/W2099258729', '')
# text revision by on the fly representation optimization, ('https://openalex.org/W4224090047', 'https://openalex.org/S4210191458'), ('https://openalex.org/W4285274433', '')
# exploring strategies for training deep neural networks, ('https://openalex.org/W3002364809', 'https://openalex.org/S118988714'), ('https://openalex.org/W2140833774', 'https://openalex.org/S118988714')
# reverse multi label learning, ('https://openalex.org/W2230678343', ''), ('https://openalex.org/W2110075577', 'https://openalex.org/S4363606243')
# uncertainty guided pixel contrastive learning for semi supervised medical image segmentation, ('https://openalex.org/W4285603459', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285603038', 'https://openalex.org/S4363608755')
# neural autoregressive distribution estimation, ('https://openalex.org/W3005090363', 'https://openalex.org/S118988714'), ('https://openalex.org/W2962990490', '')
# semi supervised maximum entropy based approach to acronym and abbreviation normalization in medical texts, ('https://openalex.org/W2152429541', ''), ('https://openalex.org/W3147159644', '')
# nonlinear models using dirichlet process mixtures, ('https://openalex.org/W3005335434', 'https://openalex.org/S118988714'), ('https://openalex.org/W2154036191', 'https://openalex.org/S118988714')
# context specific sign propagation in qualitative probabilistic networks, ('https://openalex.org/W1983780377', 'https://openalex.org/S196139623'), ('https://openalex.org/W1519419408', '')
# an empirical study on the generation of anaphora in chinese, ('https://openalex.org/W1514976329', 'https://openalex.org/S155526855'), ('https://openalex.org/W3006840971', 'https://openalex.org/S155526855')
# buildingnet learning to label d buildings, ('https://openalex.org/W4214734741', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3203025168', '')
# a closed form solution to natural image matting, ('https://openalex.org/W2308149479', ''), ('https://openalex.org/W2167897892', '')
# the roboearth language representing and exchanging knowledge about actions objects and environments, ('https://openalex.org/W2205361738', ''), ('https://openalex.org/W2050815310', '')
# breaker page, ('https://openalex.org/W4213333192', 'https://openalex.org/S199944782'), ('https://openalex.org/W4232335036', 'https://openalex.org/S199944782')
# review of formal semantics and pragmatics for natural language querying by james clifford cambridge university press, ('https://openalex.org/W3023421280', 'https://openalex.org/S155526855'), ('https://openalex.org/W1597739731', 'https://openalex.org/S155526855')
# editor s notice, ('https://openalex.org/W1555182410', 'https://openalex.org/S199944782'), ('https://openalex.org/W1604743032', 'https://openalex.org/S199944782')
# word association norms mutual information and lexicography, ('https://openalex.org/W2159637323', ''), ('https://openalex.org/W1593045043', 'https://openalex.org/S155526855')
# using emoticons to reduce dependency in machine learning techniques for sentiment classification, ('https://openalex.org/W2144378002', ''), ('https://openalex.org/W3147292827', '')
# using register diversified corpora for general language studies, ('https://openalex.org/W3010185159', 'https://openalex.org/S155526855'), ('https://openalex.org/W2126414663', 'https://openalex.org/S155526855')
# latent dirichlet allocation, ('https://openalex.org/W1880262756', 'https://openalex.org/S118988714'), ('https://openalex.org/W2151373442', 'https://openalex.org/S4363606243')
# ai ai, ('https://openalex.org/W2992869110', 'https://openalex.org/S196139623'), ('https://openalex.org/W64411697', 'https://openalex.org/S196139623')
# improving numerical accuracy of gr bner basis polynomial equation solvers, ('https://openalex.org/W1882087933', ''), ('https://openalex.org/W3148102200', '')
# spectral partitioning for structure from motion, ('https://openalex.org/W3150523862', ''), ('https://openalex.org/W1974260711', '')
# message from the program and general chairs, ('https://openalex.org/W4235434093', ''), ('https://openalex.org/W2619144031', '')
# modeling precursors for temporal knowledge graph reasoning via auto encoder structure, ('https://openalex.org/W4285600843', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285604309', 'https://openalex.org/S4363608755')
# web, ('https://openalex.org/W239008993', 'https://openalex.org/S196139623'), ('https://openalex.org/W618066528', 'https://openalex.org/S196139623')
# findings of the iwslt evaluation campaign, ('https://openalex.org/W3186200218', ''), ('https://openalex.org/W4385570170', '')
# incorporating side information by adaptive convolution, ('https://openalex.org/W2753789229', 'https://openalex.org/S4363606243'), ('https://openalex.org/W3040479127', 'https://openalex.org/S25538012')
# forthcoming papers, ('https://openalex.org/W4210519437', 'https://openalex.org/S196139623'), ('https://openalex.org/W4210668999', 'https://openalex.org/S196139623')
# in defense of one vs all classification, ('https://openalex.org/W2133864802', 'https://openalex.org/S118988714'), ('https://openalex.org/W3014813097', 'https://openalex.org/S118988714')
# annual index, ('https://openalex.org/W4244851065', 'https://openalex.org/S199944782'), ('https://openalex.org/W4213332595', 'https://openalex.org/S199944782')
# cover, ('https://openalex.org/W4233988609', 'https://openalex.org/S199944782'), ('https://openalex.org/W4255721966', 'https://openalex.org/S199944782')
# icon learning regular maps through inverse consistency, ('https://openalex.org/W4214897027', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3201812503', '')
# learning unitary operators with help from u n, ('https://openalex.org/W3023160379', 'https://openalex.org/S4210191458'), ('https://openalex.org/W2962843996', '')
# message from the general and program chairs, ('https://openalex.org/W3023925764', ''), ('https://openalex.org/W4300408057', '')
# soma solving optical marker based mocap automatically, ('https://openalex.org/W3203769524', ''), ('https://openalex.org/W4214881613', 'https://openalex.org/S4363607764')
# iterative regularization for learning with convex loss functions, ('https://openalex.org/W3022875857', 'https://openalex.org/S118988714'), ('https://openalex.org/W2964177647', '')
# mutual structure for joint filtering, ('https://openalex.org/W2199472553', ''), ('https://openalex.org/W2621247553', 'https://openalex.org/S25538012')
# online choice of active learning algorithms, ('https://openalex.org/W3014245600', 'https://openalex.org/S118988714'), ('https://openalex.org/W1666672054', '')
# stable roommate problem with diversity preferences, ('https://openalex.org/W3037428441', ''), ('https://openalex.org/W3035692363', '')
# natural language processing, ('https://openalex.org/W2100163188', 'https://openalex.org/S196139623'), ('https://openalex.org/W2336391062', 'https://openalex.org/S196139623')
# books received, ('https://openalex.org/W4249258166', 'https://openalex.org/S196139623'), ('https://openalex.org/W4251730102', 'https://openalex.org/S196139623')
# using trajectory data to improve bayesian optimization for reinforcement learning, ('https://openalex.org/W2145957964', 'https://openalex.org/S118988714'), ('https://openalex.org/W3112829623', 'https://openalex.org/S118988714')
# linked data linked services, ('https://openalex.org/W2226878251', 'https://openalex.org/S196139623'), ('https://openalex.org/W1876720153', 'https://openalex.org/S196139623')
# empirical evaluation of resampling procedures for optimising svm hyperparameters, ('https://openalex.org/W3006551545', 'https://openalex.org/S118988714'), ('https://openalex.org/W2590507395', 'https://openalex.org/S118988714')
# regularized estimation and testing for high dimensional multi block vector autoregressive models, ('https://openalex.org/W3017159290', 'https://openalex.org/S118988714'), ('https://openalex.org/W2963670397', 'https://openalex.org/S118988714')
# overview of the iwpt shared task on parsing into enhanced universal dependencies, ('https://openalex.org/W3128580990', ''), ('https://openalex.org/W3037482111', '')
# a parsing architecture based on distributed memory machines, ('https://openalex.org/W2889389124', ''), ('https://openalex.org/W2245915937', '')
# front inside cover, ('https://openalex.org/W4235103372', 'https://openalex.org/S199944782'), ('https://openalex.org/W4244323470', 'https://openalex.org/S199944782')
# etc, ('https://openalex.org/W579821188', 'https://openalex.org/S196139623'), ('https://openalex.org/W80345130', 'https://openalex.org/S196139623')
# random rotation ensembles, ('https://openalex.org/W3010411193', 'https://openalex.org/S118988714'), ('https://openalex.org/W2302010255', 'https://openalex.org/S118988714')
# wide baseline stereo matching, ('https://openalex.org/W2143753158', ''), ('https://openalex.org/W2301113010', '')
# spam filtering based on the analysis of text information embedded into images, ('https://openalex.org/W3000705115', 'https://openalex.org/S118988714'), ('https://openalex.org/W2118137541', 'https://openalex.org/S118988714')
# policy gradient in continuous time, ('https://openalex.org/W2143803054', 'https://openalex.org/S118988714'), ('https://openalex.org/W3032096424', 'https://openalex.org/S118988714')
# near optimal frequent directions for sketching dense and sparse matrices, ('https://openalex.org/W2935249184', 'https://openalex.org/S118988714'), ('https://openalex.org/W2803931841', '')
# a statistical analysis of morphemes in japanese terminology, ('https://openalex.org/W2098218697', ''), ('https://openalex.org/W4239769692', '')
# active learning using smooth relative regret approximations with applications, ('https://openalex.org/W3170332525', 'https://openalex.org/S118988714'), ('https://openalex.org/W2399210510', '')
# learning to match via inverse optimal transport, ('https://openalex.org/W3213970201', 'https://openalex.org/S118988714'), ('https://openalex.org/W2804828897', 'https://openalex.org/S118988714')
# linear convergence of randomized feasible descent methods under the weak strong convexity assumption, ('https://openalex.org/W3019640511', 'https://openalex.org/S118988714'), ('https://openalex.org/W2962704024', 'https://openalex.org/S118988714')
# minority game, ('https://openalex.org/W3168147817', 'https://openalex.org/S196139623'), ('https://openalex.org/W2904163094', 'https://openalex.org/S196139623')
# green beard effect, ('https://openalex.org/W648676845', 'https://openalex.org/S196139623'), ('https://openalex.org/W2976872597', 'https://openalex.org/S196139623')
# pri d can d priors help d representation learning, ('https://openalex.org/W4214638047', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3203737041', '')
# nonlinear boosting projections for ensemble construction, ('https://openalex.org/W3141481736', 'https://openalex.org/S118988714'), ('https://openalex.org/W1499706286', 'https://openalex.org/S118988714')
# reading between the lines, ('https://openalex.org/W233637550', ''), ('https://openalex.org/W2757376361', '')
# introduction to the special section, ('https://openalex.org/W2095109971', 'https://openalex.org/S199944782'), ('https://openalex.org/W2088170057', 'https://openalex.org/S199944782')
# www ai ai, ('https://openalex.org/W388131881', 'https://openalex.org/S196139623'), ('https://openalex.org/W437507904', 'https://openalex.org/S196139623')
# phrase detectives utilizing collective intelligence for internet scale language resource creation, ('https://openalex.org/W2272333457', ''), ('https://openalex.org/W2223961459', '')
# introduction to the workshop, ('https://openalex.org/W3014740451', ''), ('https://openalex.org/W2994842583', '')
# introduction to the special issue on learning theory, ('https://openalex.org/W2142300849', ''), ('https://openalex.org/W3071457835', 'https://openalex.org/S118988714')
# semeval task rumoureval determining rumour veracity and support for rumours, ('https://openalex.org/W2607700676', ''), ('https://openalex.org/W2954444514', '')
# unsupervised depth completion with calibrated backprojection layers, ('https://openalex.org/W3196148789', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3201883147', '')
# results of the wmt tuning shared task, ('https://openalex.org/W2252028648', ''), ('https://openalex.org/W2513167989', '')
# lr parsers for natural languages, ('https://openalex.org/W2772054157', ''), ('https://openalex.org/W2246820938', '')
# latentclr a contrastive learning approach for unsupervised discovery of interpretable directions, ('https://openalex.org/W3150608155', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202937347', '')
# a correctness result for reasoning about one dimensional planning problems, ('https://openalex.org/W2277737930', ''), ('https://openalex.org/W1574220574', '')
# preference semantics ill formedness and metaphor, ('https://openalex.org/W3083504026', 'https://openalex.org/S155526855'), ('https://openalex.org/W1510232673', 'https://openalex.org/S155526855')
# welcome message from the chairs, ('https://openalex.org/W4233517679', ''), ('https://openalex.org/W4250989655', '')
# ieee transactions on pattern analysis and machine intelligence editorial board, ('https://openalex.org/W4231256381', 'https://openalex.org/S199944782'), ('https://openalex.org/W4241181565', 'https://openalex.org/S199944782')
# visual dialog, ('https://openalex.org/W4237129069', 'https://openalex.org/S199944782'), ('https://openalex.org/W2937971956', 'https://openalex.org/S199944782')
# simulation of functions of composer and musicologist on electronic computer, ('https://openalex.org/W60144612', ''), ('https://openalex.org/W2499605024', '')
# book review, ('https://openalex.org/W125879618', 'https://openalex.org/S196139623'), ('https://openalex.org/W1607720840', 'https://openalex.org/S155526855')
# time series prediction and online learning, ('https://openalex.org/W2979756444', 'https://openalex.org/S118988714'), ('https://openalex.org/W2463652596', '')
# knowledge augmented methods for natural language processing, ('https://openalex.org/W4321485427', ''), ('https://openalex.org/W4285126771', '')
# on generating transferable targeted perturbations, ('https://openalex.org/W4214703392', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3203565179', '')
# detecting salient motion by accumulating directionally consistent flow, ('https://openalex.org/W2079241389', 'https://openalex.org/S199944782'), ('https://openalex.org/W2165741029', '')
# on the complexity of id lp parsing, ('https://openalex.org/W2108636832', 'https://openalex.org/S155526855'), ('https://openalex.org/W3146057853', 'https://openalex.org/S155526855')
# on multilabel classification and ranking with bandit feedback, ('https://openalex.org/W3018211293', 'https://openalex.org/S118988714'), ('https://openalex.org/W2117847193', 'https://openalex.org/S118988714')
# automatic extraction of aspectual information from a monolingual corpus, ('https://openalex.org/W4239613427', ''), ('https://openalex.org/W2220056965', '')
# sketchaa abstract representation for abstract sketches, ('https://openalex.org/W4214918554', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3204400728', '')
# color subspaces as photometric invariants, ('https://openalex.org/W2118209563', 'https://openalex.org/S25538012'), ('https://openalex.org/W2125529700', '')
# the fifth generation artificial intelligence and japan s computer challenge to the world, ('https://openalex.org/W2276747416', 'https://openalex.org/S196139623'), ('https://openalex.org/W114888028', 'https://openalex.org/S196139623')
# semeval task clinical tempeval, ('https://openalex.org/W2468432491', ''), ('https://openalex.org/W2917019145', '')
# sorting texts by readability, ('https://openalex.org/W2115968643', 'https://openalex.org/S155526855'), ('https://openalex.org/W4254113264', 'https://openalex.org/S155526855')
# divide and conquer for debiased l norm support vector machine in ultra high dimensions, ('https://openalex.org/W2807787126', 'https://openalex.org/S118988714'), ('https://openalex.org/W3009615294', 'https://openalex.org/S118988714')
# proceedings of the conference on empirical methods in natural language processing emnlp october grand hyatt seattle seattle washington usa a meeting of sigdat a special interest group of the acl, ('https://openalex.org/W2612844088', 'https://openalex.org/S2764948052'), ('https://openalex.org/W2597297301', 'https://openalex.org/S2764948052')
# completing any low rank matrix provably, ('https://openalex.org/W2963705450', 'https://openalex.org/S118988714'), ('https://openalex.org/W3015031642', 'https://openalex.org/S118988714')
# representation and self similarity of shapes, ('https://openalex.org/W2152229373', 'https://openalex.org/S199944782'), ('https://openalex.org/W2125710307', '')
# japanese discourse and the process of centering, ('https://openalex.org/W1700273416', 'https://openalex.org/S155526855'), ('https://openalex.org/W3006165630', 'https://openalex.org/S155526855')
# editorial, ('https://openalex.org/W4234743690', 'https://openalex.org/S199944782'), ('https://openalex.org/W2598790482', 'https://openalex.org/S196139623')
# bimal bijective maximum likelihood approach to domain adaptation in semantic scene segmentation, ('https://openalex.org/W3188258165', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202710462', '')
# a paradigm for reasoning by analogy, ('https://openalex.org/W1594794387', ''), ('https://openalex.org/W2071523700', 'https://openalex.org/S196139623')
# back cover, ('https://openalex.org/W4253430143', 'https://openalex.org/S199944782'), ('https://openalex.org/W4234001104', 'https://openalex.org/S199944782')
# list of contributors, ('https://openalex.org/W4245195218', 'https://openalex.org/S199944782'), ('https://openalex.org/W4243658090', 'https://openalex.org/S199944782')
# quasi newton methods a new direction, ('https://openalex.org/W2141706197', ''), ('https://openalex.org/W2615477230', 'https://openalex.org/S118988714')
# joint structural estimation of multiple graphical models, ('https://openalex.org/W2528307994', 'https://openalex.org/S118988714'), ('https://openalex.org/W3005125925', 'https://openalex.org/S118988714')
# parsing with flexibility dynamic strategies and idioms in mind, ('https://openalex.org/W1553416402', 'https://openalex.org/S155526855'), ('https://openalex.org/W3005073576', 'https://openalex.org/S155526855')
# an international delphi poll on future trends in information linguistics, ('https://openalex.org/W2114200152', ''), ('https://openalex.org/W2772722538', '')
# a meta mdp approach to exploration for lifelong reinforcement learning, ('https://openalex.org/W2963190967', ''), ('https://openalex.org/W2972555645', 'https://openalex.org/S4363606243')
# flexible provisioning of service workflows, ('https://openalex.org/W1582522656', ''), ('https://openalex.org/W2396289045', '')
# introducing ieee collabratec, ('https://openalex.org/W4252872099', 'https://openalex.org/S199944782'), ('https://openalex.org/W4233360753', 'https://openalex.org/S199944782')
# back cover table of contents, ('https://openalex.org/W4250858813', 'https://openalex.org/S199944782'), ('https://openalex.org/W4230550694', 'https://openalex.org/S199944782')
# a non iterative greedy algorithm for multi frame point correspondence, ('https://openalex.org/W2045516333', ''), ('https://openalex.org/W3147585036', '')
# automatic stochastic tagging of natural language texts, ('https://openalex.org/W1519945466', 'https://openalex.org/S155526855'), ('https://openalex.org/W3010377252', 'https://openalex.org/S155526855')
# pathdreamer a world model for indoor navigation, ('https://openalex.org/W3173122423', ''), ('https://openalex.org/W4214879935', 'https://openalex.org/S4363607764')
# set valued approachability and online learning with partial monitoring, ('https://openalex.org/W3085605451', 'https://openalex.org/S118988714'), ('https://openalex.org/W2172279096', 'https://openalex.org/S118988714')
# equivalence of graphical lasso and thresholding for sparse graphs, ('https://openalex.org/W2475483933', 'https://openalex.org/S118988714'), ('https://openalex.org/W2551973267', '')
# deep visual semantic alignments for generating image descriptions, ('https://openalex.org/W1905882502', ''), ('https://openalex.org/W2481240925', 'https://openalex.org/S199944782')
# large scale transductive svms, ('https://openalex.org/W2142114717', 'https://openalex.org/S118988714'), ('https://openalex.org/W3005100505', 'https://openalex.org/S118988714')
# announcements, ('https://openalex.org/W4243785313', 'https://openalex.org/S196139623'), ('https://openalex.org/W4229694013', 'https://openalex.org/S196139623')
# robust interpretable text classification against spurious correlations using and rules with negation, ('https://openalex.org/W4285605523', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285600862', 'https://openalex.org/S4363608755')
# ies, ('https://openalex.org/W651929909', 'https://openalex.org/S196139623'), ('https://openalex.org/W576034174', 'https://openalex.org/S196139623')
# use of the gibbs sampler in expert systems, ('https://openalex.org/W2033699249', 'https://openalex.org/S196139623'), ('https://openalex.org/W4240428552', 'https://openalex.org/S196139623')
# algorithmic stability and meta learning, ('https://openalex.org/W2124231679', 'https://openalex.org/S118988714'), ('https://openalex.org/W3044488908', 'https://openalex.org/S118988714')
# learning from complementary labels, ('https://openalex.org/W2963091836', 'https://openalex.org/S4363606243'), ('https://openalex.org/W2741627475', '')
# stochastic inversion transduction grammars and bilingual parsing of parallel corpora, ('https://openalex.org/W2158388102', 'https://openalex.org/S155526855'), ('https://openalex.org/W3003556534', 'https://openalex.org/S155526855')
# image analysis using hahn moments, ('https://openalex.org/W2121834080', 'https://openalex.org/S199944782'), ('https://openalex.org/W2997011548', 'https://openalex.org/S199944782')
# advances in neural information processing systems proceedings of the conference, ('https://openalex.org/W758960492', 'https://openalex.org/S4363606243'), ('https://openalex.org/W1978505713', 'https://openalex.org/S4363606243')
# imagenet classification with deep convolutional neural networks, ('https://openalex.org/W2163605009', 'https://openalex.org/S4363606243'), ('https://openalex.org/W3147600416', '')
# a word to word model of translational equivalence, ('https://openalex.org/W2788771771', ''), ('https://openalex.org/W2138787466', '')
# non rigid point set registration coherent point drift, ('https://openalex.org/W2110463399', 'https://openalex.org/S4363606243'), ('https://openalex.org/W2548252715', '')
# subgroup discovery with cn sd, ('https://openalex.org/W2998617017', 'https://openalex.org/S118988714'), ('https://openalex.org/W2113340410', 'https://openalex.org/S118988714')
# computingedge, ('https://openalex.org/W4210292413', 'https://openalex.org/S199944782'), ('https://openalex.org/W4296079267', 'https://openalex.org/S199944782')
# findings of the conference on machine translation wmt, ('https://openalex.org/W2970279348', ''), ('https://openalex.org/W3120929527', '')
# message from the general chair and program chairs, ('https://openalex.org/W4230707284', ''), ('https://openalex.org/W4247170389', '')
# guest editors introduction to the special section on perceptual organization in computer vision, ('https://openalex.org/W4233651462', 'https://openalex.org/S199944782'), ('https://openalex.org/W2148487901', 'https://openalex.org/S199944782')
# z score normalization hubness and few shot learning, ('https://openalex.org/W4214807529', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3204752714', '')
# adaptive online gradient descent, ('https://openalex.org/W3149283138', 'https://openalex.org/S4363606243'), ('https://openalex.org/W2139759436', 'https://openalex.org/S4363606243')
# on the importance of small coordinate projections, ('https://openalex.org/W2998611160', 'https://openalex.org/S118988714'), ('https://openalex.org/W2105918531', 'https://openalex.org/S118988714')
# collaborating on referring expressions, ('https://openalex.org/W2595784962', ''), ('https://openalex.org/W1541473376', 'https://openalex.org/S155526855')
# ofs ai web, ('https://openalex.org/W2992330616', 'https://openalex.org/S196139623'), ('https://openalex.org/W3004955251', 'https://openalex.org/S196139623')
# q warping direct computation of quadratic reference surfaces, ('https://openalex.org/W2111775024', ''), ('https://openalex.org/W2105689445', 'https://openalex.org/S199944782')
# machine learning and multiscale methods in the identification of bivalve larvae, ('https://openalex.org/W3144751670', ''), ('https://openalex.org/W2166319876', '')
# distributed algorithms for topic models, ('https://openalex.org/W3003241580', 'https://openalex.org/S118988714'), ('https://openalex.org/W2116137244', 'https://openalex.org/S118988714')
# human detection and segmentation via multi view consensus, ('https://openalex.org/W4214489208', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3196160568', '')
# jst, ('https://openalex.org/W3180028729', 'https://openalex.org/S25538012'), ('https://openalex.org/W3189144761', 'https://openalex.org/S196139623')
# parallel algorithm for learning optimal bayesian network structure, ('https://openalex.org/W2182389258', 'https://openalex.org/S118988714'), ('https://openalex.org/W2996787563', 'https://openalex.org/S118988714')
# ai, ('https://openalex.org/W411069133', 'https://openalex.org/S196139623'), ('https://openalex.org/W406628333', 'https://openalex.org/S196139623')
# sequential learning of classifiers for structured prediction problems, ('https://openalex.org/W3022710845', ''), ('https://openalex.org/W1902270342', 'https://openalex.org/S118988714')
# memory based parsing, ('https://openalex.org/W1975564911', 'https://openalex.org/S196139623'), ('https://openalex.org/W4251336363', 'https://openalex.org/S155526855')
# self supervised d hand pose estimation from monocular rgb via contrastive learning, ('https://openalex.org/W3202094160', ''), ('https://openalex.org/W3171333242', 'https://openalex.org/S4363607764')
# handling missing values when applying classification models, ('https://openalex.org/W2123170466', 'https://openalex.org/S118988714'), ('https://openalex.org/W3006153429', 'https://openalex.org/S118988714')
# facesimile a mobile application for face image search based on interactive shape manipulation, ('https://openalex.org/W3142040849', ''), ('https://openalex.org/W2577276809', '')
# ii, ('https://openalex.org/W356867401', 'https://openalex.org/S196139623'), ('https://openalex.org/W570285656', 'https://openalex.org/S196139623')
# smith waterman, ('https://openalex.org/W592205229', 'https://openalex.org/S196139623'), ('https://openalex.org/W2945351443', 'https://openalex.org/S196139623')
# representations of syntax mask useful effects of constituency and dependency structure in recursive lstms, ('https://openalex.org/W3129354370', 'https://openalex.org/S2764948052'), ('https://openalex.org/W3035295386', '')
# contents volume, ('https://openalex.org/W4246967405', 'https://openalex.org/S196139623'), ('https://openalex.org/W4247280968', 'https://openalex.org/S196139623')
# rethinking noise synthesis and modeling in raw denoising, ('https://openalex.org/W4214701710', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202275173', '')
# awards ijcai international joint conference on artificial intelligence, ('https://openalex.org/W4246204902', 'https://openalex.org/S196139623'), ('https://openalex.org/W4236562918', 'https://openalex.org/S196139623')
# generating attribution maps with disentangled masked backpropagation, ('https://openalex.org/W3204225367', ''), ('https://openalex.org/W3125872765', 'https://openalex.org/S4363607764')
# convolutional neural networks for text hashing, ('https://openalex.org/W2564265357', ''), ('https://openalex.org/W2218741211', '')
# market based algorithms for allocating complex tasks, ('https://openalex.org/W2489316809', ''), ('https://openalex.org/W941498152', 'https://openalex.org/S4210191458')
# bayesian multi task reinforcement learning, ('https://openalex.org/W3026384448', ''), ('https://openalex.org/W2134197408', '')
# limits of learning based superresolution algorithms, ('https://openalex.org/W2046057333', ''), ('https://openalex.org/W2114710155', 'https://openalex.org/S25538012')
# advertisement, ('https://openalex.org/W4252086612', 'https://openalex.org/S199944782'), ('https://openalex.org/W4230626864', 'https://openalex.org/S199944782')
# delayed impact of fair machine learning, ('https://openalex.org/W2965749257', ''), ('https://openalex.org/W2962753953', '')
# lexicon grammar and the syntactic analysis of french, ('https://openalex.org/W2773968696', ''), ('https://openalex.org/W2107935767', '')
# katyusha the first direct acceleration of stochastic gradient methods, ('https://openalex.org/W2884265051', 'https://openalex.org/S118988714'), ('https://openalex.org/W2963607709', '')
# support vector machinery for infinite ensemble learning, ('https://openalex.org/W2110612061', 'https://openalex.org/S118988714'), ('https://openalex.org/W3097439696', 'https://openalex.org/S118988714')
# ties matter complexity of voting manipulation revisited, ('https://openalex.org/W1569337322', ''), ('https://openalex.org/W1581672741', '')
# memory efficient max flow for multi label submodular mrfs, ('https://openalex.org/W2340034983', ''), ('https://openalex.org/W2794201696', 'https://openalex.org/S199944782')
# non uniform deblurring for shaken images, ('https://openalex.org/W2043529138', 'https://openalex.org/S25538012'), ('https://openalex.org/W2055616670', '')
# ieee computer society, ('https://openalex.org/W4254888222', 'https://openalex.org/S199944782'), ('https://openalex.org/W4233681111', 'https://openalex.org/S199944782')
# unsupervised supervised learning ii margin based classification without labels, ('https://openalex.org/W3142507814', 'https://openalex.org/S118988714'), ('https://openalex.org/W2606082972', '')
# join the ieee computer society, ('https://openalex.org/W4251740732', 'https://openalex.org/S199944782'), ('https://openalex.org/W4230915691', 'https://openalex.org/S199944782')
# learning coverage functions and private release of marginals, ('https://openalex.org/W2963650730', ''), ('https://openalex.org/W2973223731', 'https://openalex.org/S118988714')
# use of heuristic knowledge in chinese language analysis, ('https://openalex.org/W2137727802', ''), ('https://openalex.org/W2889097019', '')
# computing map trajectories by representing propagating and combining pdfs over groups, ('https://openalex.org/W3145361907', ''), ('https://openalex.org/W2124858504', '')
# predicting personal traits from facial images using convolutional neural networks augmented with facial landmark information, ('https://openalex.org/W3021350398', ''), ('https://openalex.org/W2952552312', 'https://openalex.org/S4210191458')
# learning full pairwise affinities for spectral segmentation, ('https://openalex.org/W2116373927', 'https://openalex.org/S199944782'), ('https://openalex.org/W2070884193', '')
# comment on robustness and regularization of support vector machines by h xu et al journal of machine learning research vol pp, ('https://openalex.org/W3041824598', 'https://openalex.org/S118988714'), ('https://openalex.org/W1494453817', 'https://openalex.org/S118988714')
# autonomous exploration driven by uncertainty, ('https://openalex.org/W2566974317', ''), ('https://openalex.org/W3148300437', '')
# good continuations in digital image level lines, ('https://openalex.org/W2142330934', ''), ('https://openalex.org/W3146886662', '')
# real time hand pose estimation using depth sensors, ('https://openalex.org/W3148721422', ''), ('https://openalex.org/W2407277412', '')
# learning the probability of activation in the presence of latent spreaders, ('https://openalex.org/W2775740211', 'https://openalex.org/S4210191458'), ('https://openalex.org/W2963197947', '')
# variational recursive joint estimation of dense scene structure and camera motion from monocular high speed traffic sequences, ('https://openalex.org/W2061458897', 'https://openalex.org/S25538012'), ('https://openalex.org/W2072673356', '')
# complete identification methods for the causal hierarchy, ('https://openalex.org/W3009845780', 'https://openalex.org/S118988714'), ('https://openalex.org/W2134067266', '')
# the catchment feature model for multimodal language analysis, ('https://openalex.org/W3141873736', ''), ('https://openalex.org/W2150921636', '')
# medirl predicting the visual attention of drivers via maximum entropy deep inverse reinforcement learning, ('https://openalex.org/W3119906317', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202463668', '')
# coupling vision and proprioception for navigation of legged robots, ('https://openalex.org/W4226056825', 'https://openalex.org/S4363607748'), ('https://openalex.org/W4312939545', 'https://openalex.org/S4363607701')
# detecting irregularities in images and in video, ('https://openalex.org/W2161017465', ''), ('https://openalex.org/W2026418062', 'https://openalex.org/S25538012')
# a learned representation for scalable vector graphics, ('https://openalex.org/W2966583823', ''), ('https://openalex.org/W2981679248', '')
# learning to resize images for computer vision tasks, ('https://openalex.org/W3203129146', ''), ('https://openalex.org/W4214753187', 'https://openalex.org/S4363607764')
# towards discovery and attribution of open world gan generated images, ('https://openalex.org/W3161417217', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3206711199', '')
# incentive engineering for boolean games, ('https://openalex.org/W2113140245', ''), ('https://openalex.org/W2040148146', 'https://openalex.org/S196139623')
# unsupervised person re identification via multi label classification, ('https://openalex.org/W3035402405', ''), ('https://openalex.org/W3017068813', 'https://openalex.org/S25538012')
# bi level path following for cross validated solution of kernel quantile regression, ('https://openalex.org/W1899621042', 'https://openalex.org/S118988714'), ('https://openalex.org/W3083295011', 'https://openalex.org/S118988714')
# field convolutions for surface cnns, ('https://openalex.org/W4214621635', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3202068462', '')
# learnability of gaussians with flexible variances, ('https://openalex.org/W3028809270', 'https://openalex.org/S118988714'), ('https://openalex.org/W2128345262', 'https://openalex.org/S118988714')
# bdd, ('https://openalex.org/W2625591483', 'https://openalex.org/S196139623'), ('https://openalex.org/W2626301794', 'https://openalex.org/S196139623')
# concentration inequalities for the missing mass and for histogram rule error, ('https://openalex.org/W1638306878', 'https://openalex.org/S118988714'), ('https://openalex.org/W2139741789', 'https://openalex.org/S4363606243')
# reasoning about quality and fuzziness of strategic behaviours, ('https://openalex.org/W3190823441', ''), ('https://openalex.org/W2947008279', '')
# matrix completion from noisy entries, ('https://openalex.org/W2616032753', 'https://openalex.org/S118988714'), ('https://openalex.org/W2136015602', 'https://openalex.org/S4363606243')
# are labels always necessary for classifier accuracy evaluation, ('https://openalex.org/W3180332766', ''), ('https://openalex.org/W3164560392', 'https://openalex.org/S199944782')
# message from the conference chairs, ('https://openalex.org/W2972592485', ''), ('https://openalex.org/W4376585618', '')
# predicting preference reversals via gaussian process uncertainty aversion, ('https://openalex.org/W3087601818', 'https://openalex.org/S118988714'), ('https://openalex.org/W2146364703', '')
# lira learnable imperceptible and robust backdoor attacks, ('https://openalex.org/W4214564822', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3201941857', '')
# call for papers, ('https://openalex.org/W4243776894', 'https://openalex.org/S196139623'), ('https://openalex.org/W4234710953', 'https://openalex.org/S25538012')
# learning transformations for clustering and classification, ('https://openalex.org/W3016464806', 'https://openalex.org/S118988714'), ('https://openalex.org/W2963291430', 'https://openalex.org/S118988714')
# complexity of scheduling charging in the smart grid, ('https://openalex.org/W2963582135', ''), ('https://openalex.org/W3102043009', '')
# learning optimal k space acquisition and reconstruction using physics informed neural networks, ('https://openalex.org/W4385543969', ''), ('https://openalex.org/W4313050591', 'https://openalex.org/S4363607701')
# deep supervised hashing for fast image retrieval, ('https://openalex.org/W2464915613', ''), ('https://openalex.org/W2920852583', 'https://openalex.org/S25538012')
# v matrix method of solving statistical inference problems, ('https://openalex.org/W3025461292', 'https://openalex.org/S118988714'), ('https://openalex.org/W1854718785', '')
# variable selection using svm based criteria, ('https://openalex.org/W2116948717', 'https://openalex.org/S118988714'), ('https://openalex.org/W3006489338', 'https://openalex.org/S118988714')
# introduction of new associate editors, ('https://openalex.org/W4246124684', 'https://openalex.org/S199944782'), ('https://openalex.org/W4247506677', 'https://openalex.org/S199944782')
# shallow parsing using noisy and non stationary training material, ('https://openalex.org/W3015376675', 'https://openalex.org/S118988714'), ('https://openalex.org/W2161221633', 'https://openalex.org/S118988714')
# morphological disambiguation by voting constraints, ('https://openalex.org/W2159921011', ''), ('https://openalex.org/W2788067083', '')
# how to design a three stage architecture for audio visual active speaker detection in the wild, ('https://openalex.org/W3203466265', ''), ('https://openalex.org/W3172472082', 'https://openalex.org/S4363607764')
# real time simultaneous pose and shape estimation for articulated objects using a single depth camera, ('https://openalex.org/W2337757305', 'https://openalex.org/S199944782'), ('https://openalex.org/W1977039804', '')
# real time pattern matching using projection kernels, ('https://openalex.org/W3144569959', ''), ('https://openalex.org/W2150137371', 'https://openalex.org/S199944782')
# reinforcement learning to adjust robot movements to new situations, ('https://openalex.org/W2149860990', ''), ('https://openalex.org/W2591436094', '')
# atom an analogical theory of mind, ('https://openalex.org/W2740054798', ''), ('https://openalex.org/W2782919052', '')
# an algorithm for reading dependencies from the minimal undirected independence map of a graphoid that satisfies weak transitivity, ('https://openalex.org/W2167778603', 'https://openalex.org/S118988714'), ('https://openalex.org/W3006422638', 'https://openalex.org/S118988714')
# d net for learned multi modal alignment, ('https://openalex.org/W3202288366', ''), ('https://openalex.org/W4214763741', 'https://openalex.org/S4363607764')
# deriving verbal and compositional lexical aspect for nlp applications, ('https://openalex.org/W2134185679', ''), ('https://openalex.org/W3021081734', '')
# thresholding for change detection, ('https://openalex.org/W1891609420', ''), ('https://openalex.org/W214946401', '')
# approximating context free grammars with a finite state calculus, ('https://openalex.org/W2788994750', ''), ('https://openalex.org/W2218870209', '')
# index ieee transactions on pattern analysis and machine intelligence vol pami, ('https://openalex.org/W4251239070', 'https://openalex.org/S199944782'), ('https://openalex.org/W4245580234', 'https://openalex.org/S199944782')
# bayesian canonical correlation analysis, ('https://openalex.org/W2999762899', 'https://openalex.org/S118988714'), ('https://openalex.org/W2144903813', 'https://openalex.org/S118988714')
# stochastic convex optimization with bandit feedback, ('https://openalex.org/W2137677949', ''), ('https://openalex.org/W3140456740', 'https://openalex.org/S4363606243')
# ...
# goal driven query answering for existential rules with equality, ('https://openalex.org/W2964112911', ''), ('https://openalex.org/W2768706663', 'https://openalex.org/S4210191458')
# author s reply, ('https://openalex.org/W4237472542', 'https://openalex.org/S199944782'), ('https://openalex.org/W4241908440', 'https://openalex.org/S199944782')
# reasoning with inconsistent ontologies, ('https://openalex.org/W2400823074', ''), ('https://openalex.org/W154654756', '')
# how to center deep boltzmann machines, ('https://openalex.org/W3004953731', 'https://openalex.org/S118988714'), ('https://openalex.org/W2517166081', 'https://openalex.org/S118988714')
# distinct multicolored region descriptors for object recognition, ('https://openalex.org/W4252612645', 'https://openalex.org/S199944782'), ('https://openalex.org/W2144501879', 'https://openalex.org/S199944782')
# image parsing unifying segmentation detection and recognition, ('https://openalex.org/W2056860348', 'https://openalex.org/S25538012'), ('https://openalex.org/W2171048379', '')
# structure measure a new way to evaluate foreground maps, ('https://openalex.org/W3177004386', 'https://openalex.org/S25538012'), ('https://openalex.org/W2963868681', '')
# a variance minimization criterion to active learning on graphs, ('https://openalex.org/W2885684504', 'https://openalex.org/S118988714'), ('https://openalex.org/W2135069250', '')
# comments on the core vector machines fast svm training on very large data sets, ('https://openalex.org/W3005987913', 'https://openalex.org/S118988714'), ('https://openalex.org/W2120286392', 'https://openalex.org/S118988714')
# seeking similarities over differences similarity based domain alignment for adaptive object detection, ('https://openalex.org/W3204857114', ''), ('https://openalex.org/W3202277637', 'https://openalex.org/S4363607764')
# graph structured stack and natural language parsing, ('https://openalex.org/W3140318772', ''), ('https://openalex.org/W2100948808', '')
# transfer in a multilingual mt system, ('https://openalex.org/W2889228889', ''), ('https://openalex.org/W2144025307', '')
# learning a robust relevance model for search using kernel methods, ('https://openalex.org/W2142345475', 'https://openalex.org/S118988714'), ('https://openalex.org/W3004147752', 'https://openalex.org/S118988714')
# action branching architectures for deep reinforcement learning, ('https://openalex.org/W2808114884', 'https://openalex.org/S4363606243'), ('https://openalex.org/W2769883686', 'https://openalex.org/S4210191458')
# towards universal backward compatible representation learning, ('https://openalex.org/W4285606190', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4281255819', 'https://openalex.org/S4363608755')
# indirect and conditional sensing in the event calculus, ('https://openalex.org/W130304842', ''), ('https://openalex.org/W150002670', '')
# playground, ('https://openalex.org/W86689049', 'https://openalex.org/S196139623'), ('https://openalex.org/W2978716458', 'https://openalex.org/S196139623')
# sgtr end to end scene graph generation with transformer, ('https://openalex.org/W4312563197', 'https://openalex.org/S4363607701'), ('https://openalex.org/W4388624399', 'https://openalex.org/S199944782')
# connecting language to the world, ('https://openalex.org/W3030514670', 'https://openalex.org/S196139623'), ('https://openalex.org/W2038475577', 'https://openalex.org/S196139623')
# review of the architecture of the language faculty by ray jackendoff the mit press, ('https://openalex.org/W3027685840', 'https://openalex.org/S155526855'), ('https://openalex.org/W1577745740', 'https://openalex.org/S155526855')
# incorporating the torrance and sparrow model of reflectance in uncalibrated photometric stereo, ('https://openalex.org/W2165477640', ''), ('https://openalex.org/W3151597212', '')
# coffin a computational framework for linear svms, ('https://openalex.org/W205960552', ''), ('https://openalex.org/W2186184890', '')
# sum product networks a new deep architecture, ('https://openalex.org/W2399803916', ''), ('https://openalex.org/W2040370888', '')
# low resource ner by data augmentation with prompting, ('https://openalex.org/W4285601753', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285602130', 'https://openalex.org/S4363608755')
# review of interpreting anaphors in natural language texts by david m carter ellis horwood, ('https://openalex.org/W1540600842', 'https://openalex.org/S155526855'), ('https://openalex.org/W3151545132', 'https://openalex.org/S155526855')
# a flexible pos tagger using an automatically acquired language model, ('https://openalex.org/W2884698174', ''), ('https://openalex.org/W2138903626', '')
# discriminative illumination per pixel classification of raw materials based on optimal projections of spectral brdf, ('https://openalex.org/W2082086655', 'https://openalex.org/S199944782'), ('https://openalex.org/W2114348396', '')
# supervised dimension reduction using bayesian mixture modeling, ('https://openalex.org/W2620290824', 'https://openalex.org/S118988714'), ('https://openalex.org/W67133076', '')
# learning gradients predictive models that infer geometry and statistical dependence, ('https://openalex.org/W3011173043', 'https://openalex.org/S118988714'), ('https://openalex.org/W2141864905', 'https://openalex.org/S118988714')
# mistake driven mixture of hierarchical tag context trees, ('https://openalex.org/W4237419142', ''), ('https://openalex.org/W1966320875', '')
# top down visual saliency via joint crf and dictionary learning, ('https://openalex.org/W2315287060', 'https://openalex.org/S199944782'), ('https://openalex.org/W2133858838', '')
# efficient and differentiable shadow computation for inverse problems, ('https://openalex.org/W3142700894', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3210915616', '')
# diagnosability of discrete event systems with uncertain observations, ('https://openalex.org/W2579366735', ''), ('https://openalex.org/W2922383690', '')
# text based rl agents with commonsense knowledge new challenges environments and baselines, ('https://openalex.org/W3177323726', ''), ('https://openalex.org/W3092241275', 'https://openalex.org/S4210191458')
# elf vc efficient learned flexible rate video coding, ('https://openalex.org/W4214743248', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3201795357', '')
# d topology preserving flows for viewpoint based cortical unfolding, ('https://openalex.org/W2151193506', ''), ('https://openalex.org/W2046098148', 'https://openalex.org/S25538012')
# a knowledge representation approach to understanding metaphors, ('https://openalex.org/W3148233447', 'https://openalex.org/S155526855'), ('https://openalex.org/W2125484506', 'https://openalex.org/S155526855')
# local identification of overcomplete dictionaries, ('https://openalex.org/W2963337051', 'https://openalex.org/S118988714'), ('https://openalex.org/W3019202532', 'https://openalex.org/S118988714')
# small instance detection by integer programming on object density maps, ('https://openalex.org/W3149400679', ''), ('https://openalex.org/W1908321067', '')
# harmonious attention network for person re identification, ('https://openalex.org/W2962926870', ''), ('https://openalex.org/W3143148823', '')
# aspect aspectual class and the temporal structure of narrative, ('https://openalex.org/W1544956345', 'https://openalex.org/S155526855'), ('https://openalex.org/W3003596260', 'https://openalex.org/S155526855')
# recursive segmentation and recognition templates for d parsing, ('https://openalex.org/W2121041256', ''), ('https://openalex.org/W217356789', '')
# bayesian decision process for cost efficient dynamic ranking via crowdsourcing, ('https://openalex.org/W3023592332', 'https://openalex.org/S118988714'), ('https://openalex.org/W2562019908', 'https://openalex.org/S118988714')
# hardness of identity testing for restricted boltzmann machines and potts models, ('https://openalex.org/W3188617097', ''), ('https://openalex.org/W3046349232', 'https://openalex.org/S118988714')
# relational instance based regression for relational reinforcement learning, ('https://openalex.org/W2567276317', ''), ('https://openalex.org/W2148411640', '')
# measures of uncertainty in expert systems, ('https://openalex.org/W4211258549', 'https://openalex.org/S196139623'), ('https://openalex.org/W4210589548', 'https://openalex.org/S196139623')
# efficient svm training using low rank kernel representations, ('https://openalex.org/W3006987657', 'https://openalex.org/S118988714'), ('https://openalex.org/W2137557016', 'https://openalex.org/S118988714')
# synchronization of group labelled multi graphs, ('https://openalex.org/W3202184508', ''), ('https://openalex.org/W4214710504', 'https://openalex.org/S4363607764')
# to tune or not to tune the number of trees in random forest, ('https://openalex.org/W3081554390', 'https://openalex.org/S118988714'), ('https://openalex.org/W2616207277', 'https://openalex.org/S118988714')
# robocup rescue, ('https://openalex.org/W2976151216', 'https://openalex.org/S196139623'), ('https://openalex.org/W609315612', 'https://openalex.org/S196139623')
# proceedings of the seventh workshop on statistical machine translation, ('https://openalex.org/W2611749814', 'https://openalex.org/S2764948052'), ('https://openalex.org/W1519842253', 'https://openalex.org/S2764948052')
# automatic interpretation and coding of face images using flexible models, ('https://openalex.org/W3143882204', 'https://openalex.org/S199944782'), ('https://openalex.org/W2129150631', 'https://openalex.org/S199944782')
# super resolve dynamic scene from continuous spike streams, ('https://openalex.org/W4214701068', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3203605830', '')
# lexical cohesion computed by thesaural relations as an indicator of the structure of text, ('https://openalex.org/W2997961850', 'https://openalex.org/S155526855'), ('https://openalex.org/W1710422233', 'https://openalex.org/S155526855')
# deep halftoning with reversible binary pattern, ('https://openalex.org/W3203840965', ''), ('https://openalex.org/W4214723982', 'https://openalex.org/S4363607764')
# automatic cinematography and multilingual nlg for generating video documentaries, ('https://openalex.org/W2016352209', 'https://openalex.org/S196139623'), ('https://openalex.org/W3163504568', 'https://openalex.org/S196139623')
# a statistical approach to texture classification from single images, ('https://openalex.org/W4239269065', 'https://openalex.org/S25538012'), ('https://openalex.org/W2108082645', 'https://openalex.org/S25538012')
# towards contactless low cost and accurate d fingerprint identification, ('https://openalex.org/W4249080753', 'https://openalex.org/S199944782'), ('https://openalex.org/W1970405634', '')
# finding recurrent patterns from continuous sign language sentences for automated extraction of signs, ('https://openalex.org/W2752019254', ''), ('https://openalex.org/W2997547214', 'https://openalex.org/S118988714')
# evidence estimation for bayesian partially observed mrfs, ('https://openalex.org/W2788699987', ''), ('https://openalex.org/W2780605438', '')
# semi dense stereo correspondence with dense features, ('https://openalex.org/W3013804321', ''), ('https://openalex.org/W2118934632', '')
# learning semantic lexicons from a part of speech and semantically tagged corpus using inductive logic programming, ('https://openalex.org/W2119105030', 'https://openalex.org/S118988714'), ('https://openalex.org/W3024111099', 'https://openalex.org/S118988714')
# better bounds on the adaptivity gap of influence maximization under full adoption feedback, ('https://openalex.org/W3176276744', 'https://openalex.org/S196139623'), ('https://openalex.org/W3037570485', 'https://openalex.org/S4210191458')
# capturing homomorphism closed decidable queries with existential rules extended abstract, ('https://openalex.org/W4285599918', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285605411', 'https://openalex.org/S4363608755')
# learning rules and their exceptions, ('https://openalex.org/W3028821825', 'https://openalex.org/S118988714'), ('https://openalex.org/W1564627696', 'https://openalex.org/S118988714')
# quantifier scope and constituency, ('https://openalex.org/W3027422232', ''), ('https://openalex.org/W2157959936', '')
# computing in science engineering, ('https://openalex.org/W4206522078', 'https://openalex.org/S199944782'), ('https://openalex.org/W4205792039', 'https://openalex.org/S199944782')
# max margin learning of hierarchical configural deformable templates hcdts for efficient object parsing and pose estimation, ('https://openalex.org/W2022365890', 'https://openalex.org/S25538012'), ('https://openalex.org/W3010575615', 'https://openalex.org/S25538012')
# refractive shape from light field distortion, ('https://openalex.org/W2111218333', ''), ('https://openalex.org/W1748367822', '')
# glot scaling multilingual corpora and language models to languages, ('https://openalex.org/W4377866415', ''), ('https://openalex.org/W4385570522', '')
# worst case analysis of selective sampling for linear classification, ('https://openalex.org/W2111145173', 'https://openalex.org/S118988714'), ('https://openalex.org/W3014146993', 'https://openalex.org/S118988714')
# on the spatial statistics of optical flow, ('https://openalex.org/W2130159466', ''), ('https://openalex.org/W2019661178', 'https://openalex.org/S25538012')
# resolving ambiguities to create a natural computer based sketching environment, ('https://openalex.org/W1544458978', ''), ('https://openalex.org/W2021028863', '')
# towards resolution of bridging descriptions, ('https://openalex.org/W2787992904', ''), ('https://openalex.org/W2135102358', '')
# grounded action transformation for robot learning in simulation, ('https://openalex.org/W2595845486', 'https://openalex.org/S4210191458'), ('https://openalex.org/W4297918469', 'https://openalex.org/S4210191458')
# multilabel ranking with inconsistent rankers, ('https://openalex.org/W3142256053', 'https://openalex.org/S199944782'), ('https://openalex.org/W2028851602', '')
# a native qualitative numeric planning solver based on and or graph search, ('https://openalex.org/W4285601689', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4229053050', 'https://openalex.org/S4363608755')
# efficient parallel multigrid relaxation algorithms for markov random field based low level vision applications, ('https://openalex.org/W2149500713', ''), ('https://openalex.org/W3150967811', '')
# open access, ('https://openalex.org/W4255258833', 'https://openalex.org/S199944782'), ('https://openalex.org/W4231114210', 'https://openalex.org/S199944782')
# with a little help from my friends nearest neighbor contrastive learning of visual representations, ('https://openalex.org/W3202591369', ''), ('https://openalex.org/W3158714121', 'https://openalex.org/S4363607764')
# compiling regular formalisms with rule features into finite state automata, ('https://openalex.org/W2171140781', ''), ('https://openalex.org/W2788179802', '')
# pixel difference networks for efficient edge detection, ('https://openalex.org/W4214774769', 'https://openalex.org/S4363607764'), ('https://openalex.org/W3204163701', '')
# imo interactive multi objective off policy optimization, ('https://openalex.org/W4221151330', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285602456', 'https://openalex.org/S4363608755')
# um unified multilingual multiple teacher student model for zero resource neural machine translation, ('https://openalex.org/W4285600847', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4285602055', 'https://openalex.org/S4363608755')
# combining clause learning and branch and bound for maxsat extended abstract, ('https://openalex.org/W4285602394', 'https://openalex.org/S4363608755'), ('https://openalex.org/W4391013493', '')
# improving lives of indebted farmers using deep learning predicting agricultural produce prices using convolutional neural networks, ('https://openalex.org/W3037949015', 'https://openalex.org/S4210191458'), ('https://openalex.org/W3162587016', '')

# %%
import pickle
with open(r'AI_Export\top_authors.pkl', 'rb') as fp:
    a = list(pickle.load(fp))

# wok wok wok
# 这些空白的paper的作者也被纳入了作者里面，必须直接删掉

# %%
print(len(a))
print(a[:10])
# Out:
# 118144
# ['https://openalex.org/A5025262741', 'https://openalex.org/A5015278357', 'https://openalex.org/A5016930767', 'https://openalex.org/A5058749841', 'https://openalex.org/A5074818389', 'https://openalex.org/A5040104317', 'https://openalex.org/A5034377613', 'https://openalex.org/A5083879896', 'https://openalex.org/A5078127596', 'https://openalex.org/A5003001047']

# %%
## TODO 1 最重要的点，检查我通过这样获取到的paper全不全
## TODO 2 发现一些杂音，主要是（1）title为空，title太短，（2）需要按照type和关键词过滤一下
import os
import re
import pandas as pd
from swifter import swifter

def process_title(title):
    # 使用正则表达式替换非英文字母字符为空格
    cleaned_title = re.sub(r'[^a-zA-Z]', ' ', title)
    # 合并多个连续的空格为一个空格
    cleaned_title = re.sub(r'\s+', ' ', cleaned_title)
    # 去除首尾的空格
    cleaned_title = cleaned_title.strip()
    # 将结果转换为小写
    return cleaned_title.lower()

def get_all_titles():
    title_set = set()
    for file in os.listdir('AI_Export/AI_articles'):
        df = pd.read_csv(f'AI_Export/AI_articles/{file}', header=0)
        # print(df.head(5))
        # print(df.columns)
        df['文献标题_processed'] = df['文献标题'].swifter.apply(process_title)
        title_set = title_set | set(df['文献标题_processed'].tolist())
    title_set = set([item for item in title_set if len(item.split()) > 2])
    return title_set

ALL_TITLE = get_all_titles()
# Out:
# Pandas Apply:   0%|          | 0/14295 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/12268 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/16206 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/9567 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/5908 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/10830 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/4482 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/19142 [00:00<?, ?it/s]

# %%
all_title_length = [len(item.split()) for item in ALL_TITLE if len(item.split()) <= 2]
print(len(all_title_length))
print(len(all_title_length) / len(ALL_TITLE)) # 直接 drop 掉吧
# Out:
# 0
# 0.0

# %%
retrieved_title_set = set([item[2] for item in clean_s_2])
print(len(ALL_TITLE))
print(len(ALL_TITLE & retrieved_title_set))
print(len(ALL_TITLE - retrieved_title_set))
print(len(retrieved_title_set))
# Out:
# 91076
# 72604
# 18472
# 96386

# %%
# 统计获取到的每个期刊会议 SID 的文章数量
df = pd.DataFrame(clean_s_2, columns=['Wid', 'Sid', 'title'])
df.head(10)
S_id_stats = df.groupby('Sid').size().reset_index()
S_id_stats['Sid'] = S_id_stats['Sid'].apply(lambda x:x.replace('https://openalex.org/S', 's'))
S_id_stats.to_csv('temp_export_scount.csv')
